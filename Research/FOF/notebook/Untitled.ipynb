# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/zhangyang01/Desktop/temp.xlsx')

# %%
df
# Out:
#                001105.OF    001410.OF  002554.OF  003291.OF  003456.OF  \
# 2010-03-31  0.000000e+00            0          0          0        0.0
# 2010-04-01  0.000000e+00            0          0          0        0.0
# 2010-04-02  0.000000e+00            0          0          0        0.0
# 2010-04-06  0.000000e+00            0          0          0        0.0
# 2010-04-07  0.000000e+00            0          0          0        0.0
# 2010-04-08  0.000000e+00            0          0          0        0.0
# 2010-04-09  0.000000e+00            0          0          0        0.0
# 2010-04-12  0.000000e+00            0          0          0        0.0
# 2010-04-13  0.000000e+00            0          0          0        0.0
# 2010-04-14  0.000000e+00            0          0          0        0.0
# 2010-04-15  0.000000e+00            0          0          0        0.0
# 2010-04-16  0.000000e+00            0          0          0        0.0
# ...

# %%
df.sum(axis=1).head()
# Out:
# 2010-03-31    8.593414e+09
# 2010-04-01    8.593414e+09
# 2010-04-02    8.593414e+09
# 2010-04-06    8.593414e+09
# 2010-04-07    8.593414e+09
# dtype: float64

# %%
df.head(n=1457).div(df.sum(axis=1).head(n=1457), axis=0)
# Out:
#            001105.OF  001410.OF 002554.OF 003291.OF 003456.OF 003655.OF  \
# 2010-03-31         0          0         0         0         0         0
# 2010-04-01         0          0         0         0         0         0
# 2010-04-02         0          0         0         0         0         0
# 2010-04-06         0          0         0         0         0         0
# 2010-04-07         0          0         0         0         0         0
# 2010-04-08         0          0         0         0         0         0
# 2010-04-09         0          0         0         0         0         0
# 2010-04-12         0          0         0         0         0         0
# 2010-04-13         0          0         0         0         0         0
# 2010-04-14         0          0         0         0         0         0
# 2010-04-15         0          0         0         0         0         0
# 2010-04-16         0          0         0         0         0         0
# ...

# %%
df.shape
# Out:
# (1891, 17)

# %%
df.iloc[1457:1460].div(df.sum(axis=1).iloc[1457:1460], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-a06aaac96560> in <module>()
# ----> 1 df.iloc[1457:1460].div(df.sum(axis=1).iloc[1457:1460], axis=0)
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\ops.pyc in f(self, other, axis, level, fill_value)
#    1260             return self._combine_frame(other, na_op, fill_value, level)
#    1261         elif isinstance(other, ABCSeries):
# -> 1262             return self._combine_series(other, na_op, fill_value, axis, level)
#    1263         else:
#    1264             if fill_value is not None:
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in _combine_series(self, other, func, fill_value, axis, level, try_cast)
#    3935                 return self._combine_match_index(other, func, level=level,
# ...

# %%
temp = df.iloc[1457:1460]

# %%
df['001410.OF']
# Out:
# 2010-03-31              0
# 2010-04-01              0
# 2010-04-02              0
# 2010-04-06              0
# 2010-04-07              0
# 2010-04-08              0
# 2010-04-09              0
# 2010-04-12              0
# 2010-04-13              0
# 2010-04-14              0
# 2010-04-15              0
# 2010-04-16              0
# 2010-04-19              0
# 2010-04-20              0
# 2010-04-21              0
# 2010-04-22              0
# 2010-04-23              0
# 2010-04-26              0
# 2010-04-27              0
# 2010-04-28              0
# 2010-04-29              0
# 2010-04-30              0
# 2010-05-04              0
# 2010-05-05              0
# 2010-05-06              0
# 2010-05-07              0
# 2010-05-10              0
# 2010-05-11              0
# 2010-05-12              0
# 2010-05-13              0
#                  ...
# 2017-11-24    5.43564e+08
# 2017-11-27    5.43564e+08
# 2017-11-28    5.43564e+08
# 2017-11-29    5.43564e+08
# ...

# %% [markdown]
# # 公募基金重仓股季度持股变化
#
# 计算以公募基金为主体，重仓股的季度变化

# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt
from WindPy import w
import datetime
# %matplotlib inline

# %%
w.start()
# Out:
# .ErrorCode=0
# .Data=[Already conntected!]

# %%
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=10.0.185.138;DATABASE=JYDB;UID=js_dev;PWD=js_dev')

# %%
query = 'SELECT fdo.InvestAdvisorAbbrName, t.SecuAbbr, s.SecuCode, s.SecuAbbr, f.ReportDate, f.SharesHolding, f.MarketValue \
FROM MF_KeyStockPortfolio as f, SecuMain as t, SecuMain as s, MF_FundArchives as fd, MF_InvestAdvisorOutline as fdo \
WHERE f.InnerCode = t.InnerCode \
    AND f.StockInnerCode = s.InnerCode \
    AND fd.InnerCode = f.InnerCode \
    AND fd.InvestAdvisorCode = fdo.InvestAdvisorCode \
    ORDER BY f.ReportDate DESC, f.SharesHolding DESC'

# %%
df = pd.read_sql_query(query, con=conn)

# %%
df.head()
# Out:
#   InvestAdvisorAbbrName SecuAbbr SecuCode SecuAbbr ReportDate  SharesHolding  \
# 0                  东证资管    东方红目标   601939     建设银行 2018-08-17      2200000.0
# 1                  东证资管    东方红目标   002470    金 正 大 2018-08-17      1009800.0
# 2                  东证资管    东方红目标   601668     中国建筑 2018-08-17      1000000.0
# 3                  东证资管    东方红目标   002078     太阳纸业 2018-08-17       808682.0
# 4                  东证资管    东方红目标   601166     兴业银行 2018-08-17       400000.0
#
#    MarketValue
# 0  14344000.00
# 1   6694974.00
# 2   5400000.00
# 3   6647366.04
# 4   5872000.00

# %%
df.columns = ['InvestAdvisorAbbrName', 'FundAbbr', 'SecuCode', 'SecuAbbr', 'ReportDate', 'SharesHolding', 'MarketValue']

# %%
for name in df['InvestAdvisorAbbrName'].unique():
    print name
# Out:
# 东证资管
# 华夏
# 平安大华
# 富国
# 汇添富
# 博时
# 南方
# 安信
# 华安
# 银华
# 招商
# 嘉实
# 汇丰晋信
# 中欧
# 鹏华
# 易方达
# 上投摩根
# 兴全
# 华泰柏瑞
# 光大保德信
# 中邮创业
# 新华
# 工银瑞信
# 国泰
# 景顺长城
# 九泰
# 融通
# 广发
# 申万菱信
# 华商
# 万家
# 前海开源
# 国海富兰克林
# 诺安
# 财通
# 交银施罗德
# 大成
# 中银
# 中信保诚
# 中融
# 鹏扬
# 国投瑞银
# 国联安
# 东方
# 富安达
# 泓德
# 长信
# 长盛
# 中银国际证券
# 华宝
# 民生加银
# 建信
# 海富通
# 天弘
# 农银汇理
# 宝盈
# 泰达宏利
# 诺德
# 泰康资产
# 东方阿尔法
# 东海
# 金鹰
# 浦银安盛
# 信达澳银
# 圆信永丰
# 创金合信
# 中海
# 德邦
# 银河
# 长城
# 永赢
# 金元顺安
# 东吴
# 摩根士丹利华鑫
# 国寿安保
# 方正富邦
# 华富
# 华润元大
# 天治
# 泰信
# 汇安
# 浙商
# 益民
# 红土创新
# 英大
# 长安
# 兴业
# 金信
# 太平
# 西部利得
# 前海联合
# 中金
# 中加
# 华泰保兴
# 上银
# 北信瑞丰
# 兴银
# 国金
# 浙商资管
# 富荣
# 华融证券
# 鑫元
# 中科沃土
# 先锋
# 格林
# 人保资产
# 江信
# 华泰资管
# 红塔红土
# 东兴证券
# 山西证券
# 财通资管
# 中信建投
# 恒生前海
# 国都证券
# 中航
# 长江资管
# 国开泰富
# 嘉合
# 南华
# 渤海汇金
# 新沃
# 华宸未来

# %%
comp = df[df['InvestAdvisorAbbrName'] == u'海富通']

# %%
comp_df = comp.groupby(['ReportDate', 'SecuAbbr', 'SecuCode']).sum()

# %%
comp_df = comp_df.reset_index(level=[1]).reset_index(level=[1])

# %%
comp_df['Month'] = comp_df.index.map(lambda x: x.month)
comp_df['Day'] = comp_df.index.map(lambda x: x.day)

# %%
comp_df = comp_df[(comp_df['Month'].isin([3,6,9,12])) & (comp_df['Day'].isin([30,31]))]

# %%
comp_df.head()
# Out:
#            SecuCode SecuAbbr  SharesHolding  MarketValue  Month  Day
# ReportDate
# 2003-12-31   600205    S 山东铝      3513297.0  62677218.48     12   31
# 2003-12-31   600309     万华化学      3654843.0  49815510.09     12   31
# 2003-12-31   600104     上汽集团      3313992.0  45633669.84     12   31
# 2003-12-31   990018     上港集箱      3749757.0  53246549.40     12   31
# 2003-12-31   000063     中兴通讯      2929420.0  54780154.00     12   31

# %%
comp_df['ReportDate'] = comp_df.index

# %%
dates = comp_df.index.drop_duplicates().sort_values(ascending=False).values

# %%
for next_date, prev_date in zip(dates, dates[1:]):
    next_date_hold = comp_df[comp_df.index == next_date]['SecuAbbr']
    prev_date_hold = comp_df[comp_df.index == prev_date]['SecuAbbr']
    codes = prev_date_hold.loc[~prev_date_hold.isin(next_date_hold)].values
    add_df = comp_df[comp_df['SecuAbbr'].isin(codes)].copy()
    add_df = add_df[add_df.index == prev_date]
    add_df['MarketValue'] = 0
    add_df['SharesHolding'] = 0
    add_df['ReportDate'] = next_date
    comp_df = comp_df.append(add_df)

# %%
comp_df = comp_df.sort_values('ReportDate', ascending=False)

# %%
comp_df['Diff'] = comp_df['MarketValue'] - comp_df.groupby('SecuAbbr')['MarketValue'].shift(-1)

# %%
comp_df['Diff'] = comp_df['Diff'].fillna(comp_df['MarketValue'])

# %%
comp_df['SDiff'] = comp_df['SharesHolding'] - comp_df.groupby('SecuAbbr')['SharesHolding'].shift(-1)

# %%
comp_df['SDiff'] = comp_df['SDiff'].fillna(comp_df['SharesHolding'])

# %%
comp_df = comp_df.sort_values(['ReportDate', 'SDiff'], ascending=False)

# %%
comp_df = comp_df.set_index('ReportDate')

# %%
comp_df = comp_df[comp_df.index == comp_df.index[0]]

# %%
comp_df.shape
# Out:
# (136, 8)

# %%
comp_df.dropna().shape
# Out:
# (136, 8)

# %%
comp_df
# Out:
#            SecuCode SecuAbbr  SharesHolding   MarketValue  Month  Day  \
# ReportDate
# 2018-06-30   002371     北方华创      3896800.0  1.935541e+08      6   30
# 2018-06-30   002410    广 联 达      6044027.0  1.676009e+08      6   30
# 2018-06-30   603986     兆易创新      1484407.0  1.610878e+08      6   30
# 2018-06-30   600519     贵州茅台       253493.0  1.854200e+08      6   30
# 2018-06-30   603019     中科曙光      2817606.0  1.292436e+08      6   30
# 2018-06-30   600887     伊利股份      5067022.0  1.413699e+08      6   30
# 2018-06-30   300604     长川科技      2683870.0  9.761235e+07      6   30
# 2018-06-30   600271     航天信息      3771682.0  9.531040e+07      6   30
# 2018-06-30   300373     扬杰科技      3052562.0  8.730327e+07      6   30
# 2018-06-30   000002    万  科Ａ      3597040.0  8.848718e+07      6   30
# 2018-06-30   300037    新 宙 邦      2740911.0  7.342901e+07      6   30
# 2018-06-30   600426     华鲁恒升      4119713.0  7.246575e+07      6   30
# 2018-06-30   600036     招商银行      3126968.0  8.267703e+07      6   30
# 2018-06-30   000977     浪潮信息      5097859.0  1.215839e+08      6   30
# 2018-06-30   002146     荣盛发展      5108793.0  4.459976e+07      6   30
# 2018-06-30   600879     航天电子      6309660.0  4.435691e+07      6   30
# 2018-06-30   600885     宏发股份      3959657.0  1.184729e+08      6   30
# 2018-06-30   000651     格力电器      1057194.0  4.984670e+07      6   30
# 2018-06-30   000963     华东医药      2008550.0  9.691254e+07      6   30
# 2018-06-30   600276     恒瑞医药      1189994.0  9.015395e+07      6   30
# 2018-06-30   000338     潍柴动力     11609214.0  1.015806e+08      6   30
# 2018-06-30   601318     中国平安      1143900.0  6.700966e+07      6   30
# 2018-06-30   300365     恒华科技      4602144.0  9.494223e+07      6   30
# 2018-06-30   603659    璞 泰 来       325300.0  2.078342e+07      6   30
# 2018-06-30   600056     中国医药       997409.0  1.822266e+07      6   30
# 2018-06-30   300073     当升科技       400400.0  1.363762e+07      6   30
# 2018-06-30   600884     杉杉股份       560909.0  1.239609e+07      6   30
# 2018-06-30   300601     康泰生物       198202.0  1.229843e+07      6   30
# 2018-06-30   300296    利 亚 德       920700.0  1.185862e+07      6   30
# 2018-06-30   600690     青岛海尔       542948.0  1.045718e+07      6   30
# ...             ...      ...            ...           ...    ...  ...
# 2018-06-30   600352     浙江龙盛            0.0  0.000000e+00      3   31
# 2018-06-30   601398     工商银行      5182164.0  2.756911e+07      6   30
# 2018-06-30   600030     中信证券       868461.0  1.439040e+07      6   30
# 2018-06-30   000933     神火股份            0.0  0.000000e+00      3   31
# 2018-06-30   600703     三安光电        61604.0  1.184029e+06      6   30
# 2018-06-30   603993     洛阳钼业            0.0  0.000000e+00      3   31
# 2018-06-30   000069     华侨城Ａ      9174087.0  6.632865e+07      6   30
# 2018-06-30   600048     保利地产      5184756.0  6.325402e+07      6   30
# 2018-06-30   600029     南方航空      6552373.0  5.536755e+07      6   30
# 2018-06-30   002497     雅化集团            0.0  0.000000e+00      3   31
# 2018-06-30   300316     晶盛机电     13868190.0  1.843082e+08      6   30
# 2018-06-30   002202     金风科技        54120.0  6.840768e+05      6   30
# 2018-06-30   300274     阳光电源            0.0  0.000000e+00      3   31
# 2018-06-30   601336     新华保险            0.0  0.000000e+00      3   31
# 2018-06-30   300017     网宿科技            0.0  0.000000e+00      3   31
# 2018-06-30   300459     金科文化            0.0  0.000000e+00      3   31
# 2018-06-30   601222     林洋能源            0.0  0.000000e+00      3   31
# 2018-06-30   300418     昆仑万维            0.0  0.000000e+00      3   31
# 2018-06-30   600104     上汽集团       270191.0  9.453983e+06      6   30
# 2018-06-30   601288     农业银行       334204.0  1.149662e+06      6   30
# 2018-06-30   000018     神州长城            0.0  0.000000e+00      3   31
# 2018-06-30   601688     华泰证券       800000.0  1.197600e+07      6   30
# 2018-06-30   000938     紫光股份            0.0  0.000000e+00      3   31
# 2018-06-30   002142     宁波银行            0.0  0.000000e+00      3   31
# 2018-06-30   002050     三花智控            0.0  0.000000e+00      3   31
# 2018-06-30   300618     寒锐钴业       203775.0  2.615248e+07      6   30
# 2018-06-30   300450     先导智能        19175.0  5.798520e+05      6   30
# 2018-06-30   002460     赣锋锂业        19860.0  7.661988e+05      6   30
# 2018-06-30   002466     天齐锂业        17515.0  8.685688e+05      6   30
# 2018-06-30   603799     华友钴业       260270.0  2.536852e+07      6   30
#
#                     Diff       SDiff
# ReportDate
# 2018-06-30  1.935541e+08   3896800.0
# 2018-06-30  1.676009e+08         NaN
# 2018-06-30  1.610878e+08         NaN
# 2018-06-30  1.483480e+08    199264.0
# 2018-06-30  1.292436e+08         NaN
# 2018-06-30  1.201117e+08   4320858.0
# 2018-06-30  9.761235e+07         NaN
# 2018-06-30  9.531040e+07   3771682.0
# 2018-06-30  8.730327e+07         NaN
# 2018-06-30  8.509493e+07   3495140.0
# 2018-06-30  7.342901e+07   2740911.0
# 2018-06-30  6.813784e+07   3847859.0
# 2018-06-30  6.538396e+07   2532500.0
# 2018-06-30  4.860860e+07   2134995.0
# 2018-06-30  4.459976e+07   5108793.0
# 2018-06-30  4.435691e+07   6309660.0
# 2018-06-30  4.047278e+07   2114373.0
# 2018-06-30  3.980921e+07    843175.0
# 2018-06-30  3.884076e+07   1121958.0
# 2018-06-30  3.601824e+07    567816.0
# 2018-06-30  2.699979e+07   2580058.0
# 2018-06-30  2.538505e+07    506561.0
# 2018-06-30  2.274678e+07   2997444.0
# 2018-06-30  2.078342e+07         NaN
# 2018-06-30  1.596214e+07    902309.0
# 2018-06-30  1.363762e+07    400400.0
# 2018-06-30  1.239609e+07    560909.0
# 2018-06-30  1.229843e+07         NaN
# 2018-06-30  1.185862e+07         NaN
# 2018-06-30  9.985879e+06    516200.0
# ...                  ...         ...
# 2018-06-30 -1.674000e+07  -1500000.0
# 2018-06-30 -1.894061e+07  -2454900.0
# 2018-06-30 -2.087197e+07  -1029406.0
# 2018-06-30 -2.127075e+07  -2836100.0
# 2018-06-30 -2.135462e+07   -904476.0
# 2018-06-30 -2.195048e+07  -2588500.0
# 2018-06-30 -2.517727e+07  -1931000.0
# 2018-06-30 -2.936974e+07  -1691544.0
# 2018-06-30 -3.150178e+07  -1792424.0
# 2018-06-30 -3.228328e+07  -2409200.0
# 2018-06-30 -3.813892e+07   4545174.0
# 2018-06-30 -4.151652e+07  -2274831.0
# 2018-06-30 -4.224468e+07  -2202538.0
# 2018-06-30 -5.714685e+07  -1241783.0
# 2018-06-30 -5.863806e+07  -3922278.0
# 2018-06-30 -5.993164e+07  -4733937.0
# 2018-06-30 -6.624822e+07  -8260376.0
# 2018-06-30 -6.955319e+07  -2631600.0
# 2018-06-30 -7.062314e+07  -2084326.0
# 2018-06-30 -7.748163e+07 -19776100.0
# 2018-06-30 -7.834462e+07 -12822360.0
# 2018-06-30 -8.653570e+07  -4914136.0
# 2018-06-30 -1.006568e+08  -1381700.0
# 2018-06-30 -1.087877e+08  -5716644.0
# 2018-06-30 -1.170044e+08  -6588088.0
# 2018-06-30 -1.456191e+08   -386891.0
# 2018-06-30 -1.544168e+08  -2003752.0
# 2018-06-30 -1.690177e+08  -2174297.0
# 2018-06-30 -2.049634e+08  -3477085.0
# 2018-06-30 -2.212099e+08  -1819858.0
#
# [136 rows x 8 columns]

# %%
def wind_code(x):
    if x.startswith('60'):
        return x + '.SH'
    else:
        return x + '.SZ'

# %%
data = w.wss('603345.SH', 'industry_citic', 'tradeDate=20180807;industryType=4')

# %%
print data.Data[0][0]
# Out:
# 食品饮料-食品-肉制品

# %%
today = datetime.datetime.today()
codes = comp_df['SecuCode'].apply(lambda x: wind_code(x)).tolist()
param = 'tradeDate=%s;industryType=4'%(today.strftime('%Y%m%d'))
data = w.wss(codes, 'industry_citic', param)

# %%
comp_df['industry'] = data.Data[0]

# %%
comp_df
# Out:
#            SecuCode SecuAbbr  SharesHolding   MarketValue  Month  Day  \
# ReportDate
# 2018-06-30   600276     恒瑞医药     14942398.0  1.132036e+09      6   30
# 2018-06-30   600763     通策医疗     23517012.0  1.144573e+09      6   30
# 2018-06-30   600062     华润双鹤     28907540.0  7.096801e+08      6   30
# 2018-06-30   600271     航天信息     22937108.0  5.796207e+08      6   30
# 2018-06-30   000538     云南白药      4156651.0  4.445954e+08      6   30
# 2018-06-30   002032    苏 泊 尔      8567830.0  4.412432e+08      6   30
# 2018-06-30   300037    新 宙 邦     10942350.0  2.931456e+08      6   30
# 2018-06-30   002120     韵达股份      5792553.0  2.933236e+08      6   30
# 2018-06-30   002024     苏宁易购     18250600.0  2.569684e+08      6   30
# 2018-06-30   002368     太极股份      8597982.0  2.499433e+08      6   30
# 2018-06-30   600309     万华化学      5848164.0  2.656236e+08      6   30
# 2018-06-30   600809     山西汾酒      8199712.0  5.156799e+08      6   30
# 2018-06-30   603345     安井食品      6292519.0  2.202382e+08      6   30
# 2018-06-30   000651     格力电器     54115056.0  2.551525e+09      6   30
# 2018-06-30   600884     杉杉股份      9290250.0  2.053145e+08      6   30
# 2018-06-30   601398     工商银行     61324389.0  3.262457e+08      6   30
# 2018-06-30   601799     星宇股份      8059757.0  4.826988e+08      6   30
# 2018-06-30   000895     双汇发展      7428412.0  1.961844e+08      6   30
# 2018-06-30   000963     华东医药     38008588.0  1.833914e+09      6   30
# 2018-06-30   000661     长春高新      4316874.0  9.829522e+08      6   30
# 2018-06-30   601006     大秦铁路     81194035.0  6.666030e+08      6   30
# 2018-06-30   603659    璞 泰 来      2250064.0  1.437566e+08      6   30
# 2018-06-30   600563     法拉电子      3381536.0  1.673522e+08      6   30
# 2018-06-30   601336     新华保险      6621653.0  2.839365e+08      6   30
# 2018-06-30   600529     山东药玻     11459777.0  2.788164e+08      6   30
# 2018-06-30   603900     莱绅通灵     12569948.0  2.531588e+08      6   30
# 2018-06-30   300342     天银机电     10276636.0  1.265054e+08      6   30
# 2018-06-30   300352    北 信 源     30174350.0  1.219044e+08      6   30
# 2018-06-30   002475     立讯精密      8660156.0  1.951999e+08      6   30
# 2018-06-30   603883    老 百 姓      1425767.0  1.185668e+08      6   30
# ...             ...      ...            ...           ...    ...  ...
# 2018-06-30   600030     中信证券      2269100.0  3.759899e+07      6   30
# 2018-06-30   601166     兴业银行     25103737.0  3.614938e+08      6   30
# 2018-06-30   300098    高 新 兴     10532903.0  0.000000e+00      3   31
# 2018-06-30   002415     海康威视     21052755.0  7.816888e+08      6   30
# 2018-06-30   600048     保利地产      4807200.0  5.864784e+07      6   30
# 2018-06-30   300136     信维通信        27500.0  8.450750e+05      6   30
# 2018-06-30   300003     乐普医疗      9537110.0  3.498212e+08      6   30
# 2018-06-30   000998     隆平高科      4515724.0  8.516655e+07      6   30
# 2018-06-30   600258     首旅酒店      7812861.0  0.000000e+00      3   31
# 2018-06-30   601111     中国国航     11361968.0  1.010079e+08      6   30
# 2018-06-30   002027     分众传媒      6010512.0  5.752060e+07      6   30
# 2018-06-30   600196     复星医药      2284580.0  9.455877e+07      6   30
# 2018-06-30   600456     宝钛股份     10813197.0  0.000000e+00      3   31
# 2018-06-30   300567     精测电子      2088860.0  1.662733e+08      6   30
# 2018-06-30   000786     北新建材      9350475.0  0.000000e+00      3   31
# 2018-06-30   600216     浙江医药     17094190.0  0.000000e+00      3   31
# 2018-06-30   000002    万  科Ａ      1071027.0  2.634726e+07      6   30
# 2018-06-30   601899     紫金矿业     96603100.0  3.487372e+08      6   30
# 2018-06-30   002343     慈文传媒     34631132.0  6.500263e+08      6   30
# 2018-06-30   000063     中兴通讯      9559262.0  1.245572e+08      6   30
# 2018-06-30   002439     启明星辰     43384128.0  9.206112e+08      6   30
# 2018-06-30   600438     通威股份     32878147.0  2.268592e+08      6   30
# 2018-06-30   600036     招商银行     49502362.0  1.308842e+09      6   30
# 2018-06-30   600703     三安光电      7852651.0  1.509280e+08      6   30
# 2018-06-30   002236     大华股份     28613649.0  6.452378e+08      6   30
# 2018-06-30   600176     中国巨石     33970462.0  0.000000e+00      3   31
# 2018-06-30   601318     中国平安     22190399.0  1.299914e+09      6   30
# 2018-06-30   600585     海螺水泥     12860325.0  4.305637e+08      6   30
# 2018-06-30   300274     阳光电源     18908375.0  1.696081e+08      6   30
# 2018-06-30   601012     隆基股份     26557559.0  4.432457e+08      6   30
#
#                     Diff             industry
# ReportDate
# 2018-06-30  8.699724e+08         医药-化学制药-化学制剂
# 2018-06-30  4.909832e+08       医药-其他医药医疗-医疗服务
# 2018-06-30  4.546656e+08         医药-化学制药-化学制剂
# 2018-06-30  3.289814e+08   计算机-IT服务-系统集成及IT咨询
# 2018-06-30  2.978791e+08          医药-中药生产-中成药
# 2018-06-30  2.956405e+08         家电-小家电Ⅱ-小家电Ⅲ
# 2018-06-30  2.710899e+08     基础化工-化学原料-其他化学原料
# 2018-06-30  2.699165e+08         交通运输-公交物流-物流
# 2018-06-30  2.541010e+08           商贸零售-零售-连锁
# 2018-06-30  2.499433e+08   计算机-IT服务-系统集成及IT咨询
# 2018-06-30  2.470594e+08        基础化工-化学原料-聚氨酯
# 2018-06-30  2.283048e+08         食品饮料-白酒Ⅱ-白酒Ⅲ
# 2018-06-30  2.202382e+08          食品饮料-食品-肉制品
# 2018-06-30  2.080984e+08       家电-白色家电Ⅱ-白色家电Ⅲ
# 2018-06-30  1.982338e+08  电子元器件-其他元器件Ⅱ-其他元器件Ⅲ
# 2018-06-30  1.873309e+08       银行-国有银行Ⅱ-国有银行Ⅲ
# 2018-06-30  1.871694e+08     汽车-汽车零部件Ⅱ-汽车零部件Ⅲ
# 2018-06-30  1.822950e+08          食品饮料-食品-肉制品
# 2018-06-30  1.749405e+08       医药-其他医药医疗-医药流通
# 2018-06-30  1.742171e+08       医药-生物医药Ⅱ-生物医药Ⅲ
# 2018-06-30  1.488373e+08         交通运输-公路铁路-铁路
# 2018-06-30  1.437566e+08      电子元器件-半导体Ⅱ-半导体Ⅲ
# 2018-06-30  1.436699e+08  电子元器件-其他元器件Ⅱ-其他元器件Ⅲ
# 2018-06-30  1.355690e+08        非银行金融-保险Ⅱ-保险Ⅲ
# 2018-06-30  1.331703e+08       医药-其他医药医疗-医疗器械
# 2018-06-30  1.268985e+08           商贸零售-零售-连锁
# 2018-06-30  1.265054e+08       家电-白色家电Ⅱ-白色家电Ⅲ
# 2018-06-30  1.219044e+08  计算机-计算机软件-基础软件及套装软件
# 2018-06-30  1.208218e+08  电子元器件-其他元器件Ⅱ-其他元器件Ⅲ
# 2018-06-30  1.185668e+08       医药-其他医药医疗-医药流通
# ...                  ...                  ...
# 2018-06-30 -1.425788e+08        非银行金融-证券Ⅱ-证券Ⅲ
# 2018-06-30 -1.498216e+08     银行-股份制与城商行-股份制银行
# 2018-06-30 -1.510418e+08    计算机-计算机硬件-专用计算机设备
# 2018-06-30 -1.518318e+08    电子元器件-电子设备Ⅱ-电子设备Ⅲ
# 2018-06-30 -1.572480e+08     房地产-房地产开发管理-住宅地产
# 2018-06-30 -1.641449e+08    通信-通信设备制造-通信终端及配件
# 2018-06-30 -1.669035e+08       医药-其他医药医疗-医疗器械
# 2018-06-30 -1.816742e+08           农林牧渔-农业-种子
# 2018-06-30 -2.051657e+08        餐饮旅游-酒店及餐饮-酒店
# 2018-06-30 -2.058333e+08         交通运输-航空机场-航空
# 2018-06-30 -2.116820e+08          传媒-传媒Ⅱ-整合营销
# 2018-06-30 -2.124638e+08         医药-化学制药-化学制剂
# 2018-06-30 -2.169127e+08     有色金属-稀有金属Ⅱ-稀有金属Ⅲ
# 2018-06-30 -2.334563e+08       机械-仪器仪表Ⅱ-仪器仪表Ⅲ
# 2018-06-30 -2.354450e+08  建材-其他建材-新型建材及非金属新材料
# 2018-06-30 -2.594898e+08        医药-化学制药-化学原料药
# 2018-06-30 -2.597197e+08     房地产-房地产开发管理-住宅地产
# 2018-06-30 -2.614847e+08          有色金属-贵金属-黄金
# 2018-06-30 -2.655306e+08          传媒-传媒Ⅱ-电影动画
# 2018-06-30 -2.840175e+08       通信-通信设备制造-系统设备
# 2018-06-30 -3.324147e+08  计算机-计算机软件-基础软件及套装软件
# 2018-06-30 -3.741378e+08           农林牧渔-牧业-饲料
# 2018-06-30 -4.028642e+08     银行-股份制与城商行-股份制银行
# 2018-06-30 -4.130670e+08      电子元器件-半导体Ⅱ-半导体Ⅲ
# 2018-06-30 -4.646414e+08    电子元器件-电子设备Ⅱ-电子设备Ⅲ
# 2018-06-30 -5.279010e+08           建材-玻璃Ⅱ-玻璃Ⅲ
# 2018-06-30 -5.449465e+08        非银行金融-保险Ⅱ-保险Ⅲ
# 2018-06-30 -5.614555e+08           建材-水泥Ⅱ-水泥Ⅲ
# 2018-06-30 -7.540319e+08        电力设备-新能源设备-光伏
# 2018-06-30 -9.121666e+08        电力设备-新能源设备-光伏
#
# [353 rows x 8 columns]

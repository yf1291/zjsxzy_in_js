# %%
import pandas as pd
import numpy as np
from WindPy import w
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2020 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
df = pd.read_excel('./data/spx.xlsx')

# %%
df = df.set_index('日期')

# %%
df.head()
# Out:
#                 代码     名称  开盘价(元)  最高价(元)  最低价(元)  收盘价(元)  成交额(百万)  成交量(股)
# 日期
# 1927-12-30  SPX.GI  标普500   17.66   17.66   17.66   17.66        0       0
# 1928-01-02  SPX.GI  标普500   17.66   17.66   17.66   17.66        0       0
# 1928-01-03  SPX.GI  标普500   17.76   17.76   17.76   17.76        0       0
# 1928-01-04  SPX.GI  标普500   17.72   17.72   17.72   17.72        0       0
# 1928-01-05  SPX.GI  标普500   17.55   17.55   17.55   17.55        0       0

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot(df['收盘价(元)'], color='blue')

ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.set_yscale('log')

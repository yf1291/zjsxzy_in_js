# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('D:/workspace/data/words/wst_word_count.pkl', 'rb') as f:
    word_count = pickle.load(f)

# %%
df = pd.DataFrame(word_count[u'杨洁篪'].values(), index=word_count[u'杨洁篪'].keys())

# %%
df = df.sort_index()

# %%
df.index = pd.to_datetime(df.index)

# %%
plt.figure(figsize=(16, 9))
plt.bar(df.index, df[0], width=10)
# Out:
# <Container object of 56 artists>

# %%
df
# Out:
#              0
# 2011-01-06   3
# 2011-06-09   1
# 2011-08-05   1
# 2011-10-12   1
# 2011-10-26   2
# 2011-11-06  14
# 2011-12-06   1
# 2011-12-09  13
# 2011-12-28   1
# 2012-03-08   1
# 2012-07-08   1
# 2012-07-19   1
# 2012-08-30   1
# 2012-09-10   3
# 2012-09-19   2
# 2013-04-13   2
# 2013-07-10   1
# 2013-09-06   1
# 2013-10-06   1
# 2014-04-01   1
# 2014-04-26   1
# 2014-05-19   2
# 2014-06-12   1
# 2014-07-09   3
# 2014-07-10   1
# 2014-11-13   1
# 2015-03-26   1
# 2015-04-05   3
# 2015-08-23   1
# 2015-11-05   1
# 2015-11-07   1
# 2016-01-13   2
# 2016-03-28   1
# 2016-04-01   1
# 2016-06-03   1
# 2016-06-04   1
# 2016-06-05   2
# 2016-06-06   3
# 2016-06-08   2
# 2016-12-08   1
# 2017-02-07   2
# 2017-03-11   1
# 2017-03-19   1
# 2017-04-07   3
# 2017-04-08   2
# 2017-04-17   2
# 2017-04-19   3
# 2017-06-20   1
# 2017-09-05   1
# 2017-09-13   4
# 2017-09-14   2
# 2017-11-09   1
# 2018-01-02   2
# 2018-02-10   1
# 2018-02-22   1
# 2018-03-14   1

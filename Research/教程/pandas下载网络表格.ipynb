# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dls = "https://www.newyorkfed.org/medialibrary/media/research/data_indicators/ACMTermPremium.xls"
resp = requests.get(dls)

# %%
with open('test.xls', 'wb') as output:
    output.write(resp.content)

# %%
df = pd.read_excel('./test.xls', sheetname='ACM Daily', index_col=0)

# %%
df.index
# Out:
# Index([u'14-Jun-1961', u'15-Jun-1961', u'16-Jun-1961', u'19-Jun-1961',
#        u'20-Jun-1961', u'21-Jun-1961', u'22-Jun-1961', u'23-Jun-1961',
#        u'26-Jun-1961', u'27-Jun-1961',
#        ...
#        u'23-Oct-2018', u'24-Oct-2018', u'25-Oct-2018', u'26-Oct-2018',
#        u'29-Oct-2018', u'30-Oct-2018', u'31-Oct-2018', u'01-Nov-2018',
#        u'02-Nov-2018', u'05-Nov-2018'],
#       dtype='object', name=u'DATE', length=14315)

# %%
df['ACMY10'].plot(figsize=(16, 9))

# %%
from fredapi import Fred
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fred = Fred(api_key='63c26e16e93cb78d3ef46638747ab5ef')

# %%
data = fred.get_series('SP500')

# %%
data.head()
# Out:
# 2008-06-12    1339.87
# 2008-06-13    1360.03
# 2008-06-16    1360.14
# 2008-06-17    1350.93
# 2008-06-18    1337.81
# dtype: float64

# %%
data = fred.get_series_latest_release('CHIEPUINDXM')

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.shape
# Out:
# (281L,)

# %%
data.head()
# Out:
# 1995-01-01    192.91191
# 1995-02-01    193.98785
# 1995-03-01     88.22704
# 1995-04-01    131.03471
# 1995-05-01    177.09686
# dtype: float64

# %%
info = fred.get_series_info('CHIEPUINDXM')

# %%
info
# Out:
# frequency                                                              Monthly
# frequency_short                                                              M
# id                                                                 CHIEPUINDXM
# last_updated                                            2018-06-01 10:31:03-05
# notes                        For additional details, including an analysis ...
# observation_end                                                     2018-05-01
# observation_start                                                   1995-01-01
# popularity                                                                  43
# realtime_end                                                        2018-06-13
# realtime_start                                                      2018-06-13
# seasonal_adjustment                                    Not Seasonally Adjusted
# seasonal_adjustment_short                                                  NSA
# title                              Economic Policy Uncertainty Index for China
# units                                                                    Index
# units_short                                                              Index
# dtype: object

# %%
data.plot(figsize=(16, 9), label=info['title'])
plt.legend()

# %%
fred.search('policy china')
# Out:
#             frequency frequency_short           id        last_updated  \
# series id
# CHIEPUINDXM   Monthly               M  CHIEPUINDXM 2018-06-01 15:31:03
#
#                                                          notes  \
# series id
# CHIEPUINDXM  For additional details, including an analysis ...
#
#             observation_end observation_start popularity realtime_end  \
# series id
# CHIEPUINDXM      2018-05-01        1995-01-01         43   2018-06-13
#
#             realtime_start      seasonal_adjustment seasonal_adjustment_short  \
# series id
# CHIEPUINDXM     2018-06-13  Not Seasonally Adjusted                       NSA
#
#                                                    title  units units_short
# series id
# CHIEPUINDXM  Economic Policy Uncertainty Index for China  Index       Index

# %%
personal_income_series = fred.search_by_release(175, limit=5, order_by='popularity', sort_order='desc')

# %%
personal_income_series
# Out:
#           frequency frequency_short         id        last_updated  \
# series id
# PCPI06037    Annual               A  PCPI06037 2017-11-30 17:01:02
# PCPI06075    Annual               A  PCPI06075 2017-11-30 17:01:02
# PCPI06073    Annual               A  PCPI06073 2017-11-30 17:01:02
# PCPI36061    Annual               A  PCPI36061 2017-11-30 17:01:03
# PCPI12086    Annual               A  PCPI12086 2017-11-30 17:01:03
#
#                                                        notes observation_end  \
# series id
# PCPI06037  Personal income is the income that is received...      2016-01-01
# PCPI06075  Personal income is the income that is received...      2016-01-01
# PCPI06073  Personal income is the income that is received...      2016-01-01
# PCPI36061  Personal income is the income that is received...      2016-01-01
# PCPI12086  Personal income is the income that is received...      2016-01-01
#
#           observation_start popularity realtime_end realtime_start  \
# series id
# PCPI06037        1969-01-01         45   2018-06-13     2018-06-13
# PCPI06075        1969-01-01         29   2018-06-13     2018-06-13
# PCPI06073        1969-01-01         25   2018-06-13     2018-06-13
# PCPI36061        1969-01-01         25   2018-06-13     2018-06-13
# PCPI12086        1969-01-01         19   2018-06-13     2018-06-13
#
#                seasonal_adjustment seasonal_adjustment_short  \
# series id
# PCPI06037  Not Seasonally Adjusted                       NSA
# PCPI06075  Not Seasonally Adjusted                       NSA
# PCPI06073  Not Seasonally Adjusted                       NSA
# PCPI36061  Not Seasonally Adjusted                       NSA
# PCPI12086  Not Seasonally Adjusted                       NSA
#
#                                                        title    units  \
# series id
# PCPI06037  Per Capita Personal Income in Los Angeles Coun...  Dollars
# PCPI06075  Per Capita Personal Income in San Francisco Co...  Dollars
# PCPI06073  Per Capita Personal Income in San Diego County...  Dollars
# PCPI36061  Per Capita Personal Income in New York County, NY  Dollars
# PCPI12086  Per Capita Personal Income in Miami-Dade Count...  Dollars
#
#           units_short
# series id
# PCPI06037           $
# PCPI06075           $
# PCPI06073           $
# PCPI36061           $
# PCPI12086           $

# %%
df = {}
df['SF'] = fred.get_series('PCPI06075')
df['NY'] = fred.get_series('PCPI36061')
df['DC'] = fred.get_series('PCPI11001')
df = pd.DataFrame(df)

# %%
df.plot(figsize=(16, 9))

# %%
df = fred.search_by_category(101, limit=10, order_by='popularity', sort_order='desc')

# %%
df['title']
# Out:
# series id
# TOTALSL            Total Consumer Credit Owned and Securitized, O...
# SLOAS               Student Loans Owned and Securitized, Outstanding
# TERMCBAUTO48NS     Finance Rate on Consumer Installment Loans at ...
# MVLOAS             Motor Vehicle Loans Owned and Securitized, Out...
# REVOLSL            Total Revolving Credit Owned and Securitized, ...
# TERMCBCCALLNS      Commercial Bank Interest Rate on Credit Card P...
# TERMCBPER24NS      Finance Rate on Personal Loans at Commercial B...
# RIFLPBCIANM60NM    Finance Rate on Consumer Installment Loans at ...
# TERMCBCCINTNS      Commercial Bank Interest Rate on Credit Card P...
# TOTALNS            Total Consumer Credit Owned and Securitized, O...
# Name: title, dtype: object

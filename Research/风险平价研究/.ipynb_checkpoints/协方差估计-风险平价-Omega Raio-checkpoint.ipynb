# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
from scipy.optimize import minimize, basinhopping
from sklearn import preprocessing
from sklearn.covariance import LedoitWolf, EmpiricalCovariance, ShrunkCovariance, OAS, GraphLassoCV, MinCovDet, GraphLasso
import empyrical
# %matplotlib inline

# %%
DATA_DIR = 'D:/workspace/zjsxzy_in_js/Research/data/'

# %% [markdown]
# # 读数据

# %%
fname = '%s/assets.xlsx'%(DATA_DIR)
print fname
# Out:
# D:/workspace/zjsxzy_in_js/Research/data//assets.xlsx

# %%
odf = pd.read_excel(fname, index_col=0)

# %%
odf.tail()
# Out:
#             881001.WI    HSI.HI   SPX.GI  CBA00101.CS  AU9999.SGE  B.IPE  \
# 2018-07-18  3813.5347  28117.42  2815.62     181.2749      265.47  73.06
# 2018-07-19  3792.2334  28010.86  2804.49     181.4888      266.29  72.70
# 2018-07-20  3851.2965  28224.48  2801.83     181.4993      267.48  73.07
# 2018-07-23  3883.1899  28256.12  2806.98     181.5767      268.40  73.26
# 2018-07-24  3945.4412  28662.57  2820.40     181.4481      268.43  74.15
#
#             H11025.CSI    CCFI.WI
# 2018-07-18   1488.7237  1065.4121
# 2018-07-19   1488.8743  1079.6532
# 2018-07-20   1489.0281  1082.2548
# 2018-07-23   1489.4725  1091.8285
# 2018-07-24   1489.6274  1091.1258

# %% [markdown]
# # 标准风险平价

# %%
 # 风险预算优化
def calculate_portfolio_var(w, V):
    # 计算组合风险的函数
    return w.dot(V).dot(w)

# %%
def calculate_risk_contribution(w ,V):
    # 边际风险贡献
    MRC = V.dot(w)
    # 风险贡献
    RC = w * MRC
    return RC

# %%
def risk_budget_objective(x, pars):
    # 计算组合风险
    V = pars[0]# 协方差矩阵
    MRC = V.dot(x)
    ARC = x * MRC
    J = np.sum([(i-j)**2 for i in ARC for j in ARC])
#     J = x.dot(MRC) - np.log(x).sum()
#     J = calculate_portfolio_var(x, V) - np.log(x).sum()
#     J = sum(np.square(asset_RC - risk_target.T))[0, 0] # sum of squared error
#     J = np.abs(asset_RC.max() - asset_RC.min())
    return J

# %%
def total_weight_constraint(x):
    return np.sum(x) - 1.0

# %%
def long_only_constraint(x):
    return x

# %%
def vol_constraint(x):
    return np.concatenate((x, np.array([np.sqrt(calculate_portfolio_var(x, cov)) - 0.002])))

# %%
# 根据资产预期目标风险贡献度来计算各资产的权重
def calcu_w(V):
    N = V.shape[0]
    w0 = np.random.random_sample((N,))
    w0 /= w0.sum()
    cons = ({'type': 'eq', 'fun': total_weight_constraint},
            {'type': 'ineq', 'fun': long_only_constraint})
    minimizer_args = {'method': 'SLSQP', 'args': [V], 'constraints': cons}
#     minimizer_args = {'method': 'L-BFGS-B', 'args': [V], 'bounds': np.array([(0., None)]*N)}
#     weight = res.x / res.x.sum()
    res = basinhopping(risk_budget_objective, w0, stepsize=1e-8, minimizer_kwargs=minimizer_args)
#     res = minimize(risk_budget_objective, w0, args=[V], method='SLSQP',constraints=cons)
    return res.x

# %%
def metric(daily_ret):
    an_ret = empyrical.annual_return(daily_ret)
    sharpe = empyrical.sharpe_ratio(daily_ret)
    vol = empyrical.annual_volatility(daily_ret)
    maxdraw = empyrical.max_drawdown(daily_ret)
    print 'Annual return: %.2f%%'%(an_ret*100)
    print 'Sharpe ratio: %.2f'%(sharpe)
    print 'Annual volatility: %.2f%%'%(vol*100)
    print 'Max drawdown: %.2f%%'%(maxdraw*100)

# %% [markdown]
# # sample covariance

# %%
df = odf[['881001.WI', 'CBA00101.CS', 'CCFI.WI']]

# %%
df = df.replace([0], np.NAN)

# %%
# df = df[df['B.IPE'] > 0]

# %%
# df = df[df.index >= '2012-01-01']

# %%
ret_df = df.pct_change().dropna()

# %%
ret_df.head()
# Out:
#             881001.WI  CBA00101.CS   CCFI.WI
# 2002-01-07  -0.011381     0.000418  0.000000
# 2002-01-08  -0.008333    -0.001876  0.027092
# 2002-01-09  -0.018304     0.001933  0.001645
# 2002-01-10   0.008978    -0.000886 -0.002444
# 2002-01-11  -0.027818     0.003406  0.000065

# %%
cov = ret_df.cov()

# %%
cov
# Out:
#                 881001.WI   CBA00101.CS       CCFI.WI
# 881001.WI    3.110918e-04 -1.323418e-07  6.048258e-05
# CBA00101.CS -1.323418e-07  1.339817e-06 -5.268911e-07
# CCFI.WI      6.048258e-05 -5.268911e-07  1.627657e-04

# %%
w = np.array([1. / df.shape[1]] * df.shape[1])

# %%
rc = calculate_risk_contribution(w, cov)

# %%
rc
# Out:
# 881001.WI      4.127134e-05
# CBA00101.CS    7.562051e-08
# CCFI.WI        2.474682e-05
# dtype: float64

# %%
wb = calcu_w(cov*10000)

# %%
wb
# Out:
# array([0.0502619 , 0.87901669, 0.07072146])

# %%
rc = calculate_risk_contribution(wb, cov)

# %%
rc
# Out:
# 881001.WI      9.950423e-07
# CBA00101.CS    9.966358e-07
# CCFI.WI        9.963134e-07
# dtype: float64

# %%
np.sqrt(calculate_portfolio_var(wb, cov))
# Out:
# 0.001728580785314102

# %% [markdown]
# # 回测

# %%
new_df = df[(df.index >= ret_df.index[0]) & (df.index <= ret_df.index[-1])]

# %%
# rebalance_dates = set(new_df.resample('BQ').last().index)
months = pd.Series(new_df.index.map(lambda x: (x.year, x.month)), index=new_df.index)
rebalance_dates = months.drop_duplicates(keep='last').index

# %%
rebalance_dates
# Out:
# DatetimeIndex(['2010-10-29', '2010-11-30', '2010-12-31', '2011-01-31',
#                '2011-02-28', '2011-03-31', '2011-04-29', '2011-05-31',
#                '2011-06-30', '2011-07-29', '2011-08-31', '2011-09-30',
#                '2011-10-31', '2011-11-30', '2011-12-30', '2012-01-31',
#                '2012-02-29', '2012-03-30', '2012-04-27', '2012-05-31',
#                '2012-06-29', '2012-07-31', '2012-08-31', '2012-09-28',
#                '2012-10-31', '2012-11-30', '2012-12-31', '2013-01-31',
#                '2013-02-28', '2013-03-29', '2013-04-26', '2013-05-31',
#                '2013-06-28', '2013-07-31', '2013-08-30', '2013-09-30',
#                '2013-10-31', '2013-11-29', '2013-12-31', '2014-01-30',
#                '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-30',
#                '2014-06-30', '2014-07-31', '2014-08-29', '2014-09-30',
#                '2014-10-31', '2014-11-28', '2014-12-31', '2015-01-30',
#                '2015-02-27', '2015-03-31', '2015-04-30', '2015-05-29',
#                '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30',
#                '2015-10-30', '2015-11-30', '2015-12-31', '2016-01-29',
#                '2016-02-29', '2016-03-31', '2016-04-29', '2016-05-31',
#                '2016-06-30', '2016-07-29', '2016-08-31', '2016-09-30',
#                '2016-10-31', '2016-11-30', '2016-12-30', '2017-01-26',
#                '2017-02-28', '2017-03-31', '2017-04-28', '2017-05-31',
#                '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-06'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## 等权策略

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        wb = np.array([0.25/3, 0.25/3, 0.25/3, 0.25, 0.25, 0.25])

# %%
equal_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
equal_portfolio_ret = equal_portfolio_ret[equal_portfolio_ret != 0]

# %%
metric(equal_portfolio_ret)
# Out:
# Annual return: 2.57%
# Sharpe ratio: 0.30
# Annual volatility: 10.08%
# Max drawdown: -27.71%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
# plt.plot((1+ret_df['881001.WI']).cumprod(), label='881001.WI')
# plt.plot((1+ret_df['HSI.HI']).cumprod(), label='HSI.HI')
# plt.plot((1+ret_df['SPX.GI']).cumprod(), label='SPX.GI')
# plt.plot((1+ret_df['065.CS']).cumprod(), label='065.CS')
# plt.plot((1+ret_df['AU9999.SGE']).cumprod(), label='AU9999.SGE')
# plt.plot((1+ret_df['B.IPE']).cumprod(), label='B.IPE')
plt.legend()

# %% [markdown]
# ## sample covariance 风险平价

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        cov = ret_df[ret_df.index <= date][-60:].cov()
        wb = calcu_w(cov*10000)

# %%
sample_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
sample_portfolio_ret = sample_portfolio_ret[sample_portfolio_ret != 0]

# %%
metric(sample_portfolio_ret)
# Out:
# Annual return: 5.42%
# Sharpe ratio: 1.94
# Annual volatility: 2.75%
# Max drawdown: -3.60%

# %%
# weight.iloc[-1] = wb

# %%
# weight.drop_duplicates().to_excel('C:/Users/jgtzsx01/Desktop/volatility.xlsx')

# %%
# ((1+sample_portfolio_ret).cumprod()).to_csv('C:/Users/jgtzsx01/Desktop/volatility.csv')

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
# plt.plot((1+ret_df['881001.WI']).cumprod(), label='881001.WI')
# plt.plot((1+ret_df['HSI.HI']).cumprod(), label='HSI.HI')
# plt.plot((1+ret_df['SPX.GI']).cumprod(), label='SPX.GI')
# plt.plot((1+ret_df['065.CS']).cumprod(), label='065.CS')
# plt.plot((1+ret_df['AU9999.SGE']).cumprod(), label='AU9999.SGE')
# plt.plot((1+ret_df['B.IPE']).cumprod(), label='B.IPE')
plt.legend()

# %% [markdown]
# # 以Downside Omega Ratio作为风险指标

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
#         print date
#         free_return = odf[odf.index <= date]['H11025.CSI'][-60:]
        past_return = ret_df[ret_df.index <= date][-60:]
#         risk_free = free_return[-1] / free_return[-2] - 1
        risk_free = 0
        wb = 1. / -past_return[past_return < risk_free].sum()
        wb /= wb.sum()

# %%
omega_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
omega_portfolio_ret = omega_portfolio_ret[omega_portfolio_ret != 0]

# %%
# weight.iloc[-1] = wb

# %%
# weight.drop_duplicates().to_excel('C:/Users/jgtzsx01/Desktop/omega.xlsx')

# %%
# ((1+omega_portfolio_ret).cumprod()).to_csv('C:/Users/jgtzsx01/Desktop/omega.csv')

# %%
metric(omega_portfolio_ret)
# Out:
# Annual return: 5.48%
# Sharpe ratio: 2.17
# Annual volatility: 2.47%
# Max drawdown: -2.87%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='volatility risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
# plt.plot((1+ret_df['881001.WI']).cumprod(), label='881001.WI')
# plt.plot((1+ret_df['HSI.HI']).cumprod(), label='HSI.HI')
# plt.plot((1+ret_df['SPX.GI']).cumprod(), label='SPX.GI')
# plt.plot((1+ret_df['065.CS']).cumprod(), label='065.CS')
# plt.plot((1+ret_df['AU9999.SGE']).cumprod(), label='AU9999.SGE')
# plt.plot((1+ret_df['B.IPE']).cumprod(), label='B.IPE')
plt.legend()

# %%
weight.tail()
# Out:
#             881001.WI     HSI.HI     SPX.GI    065.CS AU9999.SGE      B.IPE
# 2017-08-31   0.041754  0.0651965  0.0893916  0.729563  0.0561833  0.0179113
# 2017-09-01  0.0354088  0.0319045    0.05196  0.832038   0.035602  0.0130863
# 2017-09-04  0.0354088  0.0319045    0.05196  0.832038   0.035602  0.0130863
# 2017-09-05  0.0354088  0.0319045    0.05196  0.832038   0.035602  0.0130863
# 2017-09-06  0.0354088  0.0319045    0.05196  0.832038   0.035602  0.0130863

# %%
wb
# Out:
# 881001.WI     0.040756
# HSI.HI        0.033210
# SPX.GI        0.050996
# 065.CS        0.819883
# AU9999.SGE    0.040858
# B.IPE         0.014297
# dtype: float64

# %% [markdown]
# ## 用真实协方差来调仓

# %%
real_weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
for date in new_df.index:
    real_weight.loc[date] = wb
    if date in rebalance_dates:
        cov = ret_df[ret_df.index >= date][:30].cov()
        wb = calcu_w(cov*10000)

# %%
real_portfolio_ret = (real_weight * ret_df).sum(axis=1)

# %%
real_portfolio_ret = real_portfolio_ret[real_portfolio_ret != 0]

# %%
metric(real_portfolio_ret)
# Out:
# Annual return: 5.04%
# Sharpe ratio: 2.24
# Annual volatility: 2.21%
# Max drawdown: -2.94%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
plt.plot((1+real_portfolio_ret).cumprod(), label='real covariance risk parity')
# plt.plot((1+ret_df['881001.WI']).cumprod(), label='881001.WI')
# plt.plot((1+ret_df['HSI.HI']).cumprod(), label='HSI.HI')
# plt.plot((1+ret_df['SPX.GI']).cumprod(), label='SPX.GI')
# plt.plot((1+ret_df['065.CS']).cumprod(), label='065.CS')
# plt.plot((1+ret_df['AU9999.SGE']).cumprod(), label='AU9999.SGE')
# plt.plot((1+ret_df['B.IPE']).cumprod(), label='B.IPE')
plt.legend()

# %% [markdown]
# ## Empirical covariance

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
ec = EmpiricalCovariance(assume_centered=True)
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        X_train = ret_df[ret_df.index <= date][-30:]
        ec.fit(X_train)
        wb = calcu_w(ec.covariance_*10000)

# %%
ec_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
ec_portfolio_ret = ec_portfolio_ret[ec_portfolio_ret != 0]

# %%
metric(ec_portfolio_ret)
# Out:
# Annual return: 5.74%
# Sharpe ratio: 1.96
# Annual volatility: 2.87%
# Max drawdown: -3.81%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
plt.plot((1+ec_portfolio_ret).cumprod(), label='ec covariance risk parity')
plt.legend()

# %% [markdown]
# ## Ledoit-Wolf shrinkage

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
lw = LedoitWolf()
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        X_train = ret_df[ret_df.index <= date][-30:]
        lw.fit(X_train)
        wb = calcu_w(lw.covariance_*10000)
#         print wb * (lw.covariance_.dot(wb))

# %%
weight.drop_duplicates()
# Out:
#             881001.WI     HSI.HI     SPX.GI    065.CS AU9999.SGE        B.IPE
# 2010-10-26          0          0          0         0          0            0
# 2010-11-01   0.146823    0.13417   0.177327  0.184953   0.176694     0.180032
# 2010-12-01  0.0690289  0.0911907   0.149072  0.437834   0.173925    0.0789496
# 2011-01-04   0.107109   0.112724   0.150525  0.349339   0.194089    0.0862138
# 2011-02-01    0.08228   0.118748    0.19339  0.320085   0.174396     0.111101
# 2011-03-01  0.0964134   0.132656   0.165904  0.331793   0.189317    0.0839172
# 2011-04-01    0.13663   0.110621   0.157366  0.310408   0.208331    0.0766445
# 2011-05-03   0.158381   0.104955   0.167985  0.317657   0.171853    0.0791692
# 2011-06-01   0.131054    0.12409   0.183775  0.328285   0.178853    0.0539431
# 2011-07-01   0.136934   0.106522   0.111822  0.299645   0.274789    0.0702878
# 2011-08-01   0.155815   0.123817   0.141262  0.257454   0.210899     0.110754
# 2011-09-01    0.16362   0.152757  0.0901628  0.259282   0.215215     0.118963
# 2011-10-10   0.167221    0.10405   0.152296  0.306449   0.142233     0.127751
# 2011-11-01   0.170937   0.106968   0.149144  0.316217   0.134699     0.122035
# 2011-12-01   0.144882  0.0794299     0.1092  0.377224   0.144422     0.144842
# 2012-01-04     0.1601   0.135956   0.166098  0.245974   0.154286     0.137585
# 2012-02-01   0.142716   0.157422   0.183023  0.252469    0.14319      0.12118
# 2012-03-01  0.0968348   0.113625   0.216107  0.284098   0.146328     0.143007
# 2012-04-05   0.102631   0.138373    0.18118  0.307242   0.141168     0.129405
# 2012-05-02   0.105146   0.141214    0.17098  0.319639   0.142463     0.120559
# 2012-06-01   0.142801  0.0908711   0.143235  0.378471   0.137562      0.10706
# 2012-07-02   0.152378   0.103537   0.133826  0.384035   0.148317    0.0779069
# 2012-08-01   0.137082   0.085135   0.104532  0.429427   0.175739    0.0680847
# 2012-09-03   0.153242   0.105659   0.157406  0.289583   0.178234     0.115875
# 2012-10-08  0.0984618   0.108275   0.203814  0.326555   0.158414      0.10448
# 2012-11-01  0.0998662   0.128158   0.184312  0.333663   0.159365    0.0946356
# 2012-12-03   0.122886   0.134898   0.154902  0.296023    0.17689       0.1144
# 2013-01-04  0.0861811   0.146006   0.161138  0.289742   0.164526     0.152407
# 2013-02-01   0.115027   0.145549   0.143162  0.240793   0.194518     0.160951
# 2013-03-01  0.0879272   0.153013   0.174424  0.290761   0.156938     0.136937
# ...               ...        ...        ...       ...        ...          ...
# 2015-02-02   0.106488   0.181001   0.161987  0.277973   0.182513    0.0900376
# 2015-03-02   0.096323   0.195355   0.164385  0.304587   0.166953    0.0723967
# 2015-04-01   0.108674    0.15195   0.138135  0.366913   0.180333    0.0539943
# 2015-05-04  0.0937337   0.134106   0.218611  0.297472   0.178856    0.0772216
# 2015-06-01  0.0692833   0.147002   0.200794  0.280709   0.187283     0.114929
# 2015-07-01  0.0434075   0.126218    0.17023  0.310843   0.267886    0.0814141
# 2015-08-03  0.0311355  0.0736017   0.179096  0.419227    0.21175    0.0851892
# 2015-09-01  0.0527002    0.13436   0.146738  0.298403    0.29504    0.0727574
# 2015-10-08  0.0573043   0.110502   0.133227  0.324904   0.308634    0.0654287
# 2015-11-02   0.101861   0.126949   0.156382  0.294702   0.218939     0.101166
# 2015-12-01   0.081704   0.169052   0.179163   0.27981   0.181134     0.109138
# 2016-01-04   0.106639   0.150023   0.152897  0.283617    0.20128     0.105544
# 2016-02-01  0.0760897   0.130647    0.13657   0.29195   0.296499    0.0682436
# 2016-03-01   0.082818   0.153767   0.138702  0.318209   0.247323    0.0591811
# 2016-04-01  0.0876236   0.137398   0.178307  0.316963   0.190263    0.0894455
# 2016-05-03   0.114921   0.127795   0.199571  0.300859   0.173765    0.0830883
# 2016-06-01  0.0972761   0.138257    0.19515   0.26233   0.220056    0.0869302
# 2016-07-01   0.114796   0.122429   0.151926  0.263416   0.268727    0.0787063
# 2016-08-01   0.149099   0.140621   0.148478  0.282499   0.219187    0.0601152
# 2016-09-01   0.112601    0.16177   0.209477  0.280986   0.178543    0.0566225
# 2016-10-10   0.128994   0.126022   0.155745  0.348205   0.182213    0.0588218
# 2016-11-01   0.141062   0.129441   0.151638  0.256006   0.232047     0.089806
# 2016-12-01   0.205342   0.141512   0.171357  0.260673   0.161853     0.059263
# 2017-01-03   0.143804   0.149778   0.217872  0.225318   0.178586    0.0846416
# 2017-02-03   0.140617   0.124415   0.255253  0.291486   0.188229 -7.08805e-09
# 2017-03-01   0.116031   0.154136   0.189152  0.266353   0.176713    0.0976159
# 2017-04-05   0.157942    0.14798   0.200531  0.254843    0.15568    0.0830248
# 2017-05-02   0.133434   0.120299   0.219944  0.262486   0.161851     0.101986
# 2017-06-01   0.142826   0.147142   0.195844  0.283197   0.164797    0.0661944
# 2017-07-03    0.15278   0.132803   0.164576  0.289158   0.182786    0.0778971
#
# [82 rows x 6 columns]

# %%
lw_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
lw_portfolio_ret = lw_portfolio_ret[lw_portfolio_ret != 0]

# %%
metric(lw_portfolio_ret)
# Out:
# Annual return: 4.84%
# Sharpe ratio: 0.67
# Annual volatility: 7.46%
# Max drawdown: -15.64%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+lw_portfolio_ret).cumprod(), label='lw covariance risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
plt.legend()

# %% [markdown]
# ## Shrunk Covariance

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
sc = ShrunkCovariance(0.01)
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        X_train = ret_df[ret_df.index <= date][-30:]
        sc.fit(X_train)
        wb = calcu_w(sc.covariance_*10000)

# %%
sc_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
sc_portfolio_ret = sc_portfolio_ret[sc_portfolio_ret != 0]

# %%
metric(sc_portfolio_ret)
# Out:
# Annual return: 5.33%
# Sharpe ratio: 0.85
# Annual volatility: 6.34%
# Max drawdown: -13.21%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
plt.plot((1+lw_portfolio_ret).cumprod(), label='lw covariance risk parity')
plt.plot((1+sc_portfolio_ret).cumprod(), label='shrunk covariance risk parity')
plt.legend()

# %% [markdown]
# ## Oracle Approximating Shrinkage

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
oas = OAS()
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        X_train = ret_df[ret_df.index <= date][-30:]
        oas.fit(X_train)
        wb = calcu_w(oas.covariance_*10000)

# %%
oas_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
oas_portfolio_ret = oas_portfolio_ret[oas_portfolio_ret != 0]

# %%
metric(oas_portfolio_ret)
# Out:
# Annual return: 4.90%
# Sharpe ratio: 0.69
# Annual volatility: 7.30%
# Max drawdown: -14.94%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+omega_portfolio_ret).cumprod(), label='omega risk parity')
plt.plot((1+lw_portfolio_ret).cumprod(), label='lw covariance risk parity')
plt.plot((1+sc_portfolio_ret).cumprod(), label='shrunk covariance risk parity')
plt.plot((1+oas_portfolio_ret).cumprod(), label='oas covariance risk parity')
plt.legend()

# %% [markdown]
# ## Robust Covariance Estimation

# %%
weight = pd.DataFrame(columns=new_df.columns, index=new_df.index)
wb = np.array([0, 0, 0, 0, 0, 0])
mcd = MinCovDet()
for date in new_df.index:
    weight.loc[date] = wb
    if date in rebalance_dates:
        X_train = ret_df[ret_df.index <= date][-60:]
        mcd.fit(X_train)
        wb = calcu_w(mcd.covariance_*10000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-488-61b1cdef03aa> in <module>()
#       6     if date in rebalance_dates:
#       7         X_train = ret_df[ret_df.index <= date][-60:]
# ----> 8         mcd.fit(X_train)
#       9         wb = calcu_w(mcd.covariance_*10000)
#
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\covariance\robust_covariance.pyc in fit(self, X, y)
#     617             X, support_fraction=self.support_fraction,
#     618             cov_computation_method=self._nonrobust_covariance,
# --> 619             random_state=random_state)
#     620         if self.assume_centered:
#     621             raw_location = np.zeros(n_features)
#
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\covariance\robust_covariance.pyc in fast_mcd(X, support_fraction, cov_computation_method, random_state)
#     485             X, n_support, n_trials=n_trials, select=n_best, n_iter=2,
#     486             cov_computation_method=cov_computation_method,
# --> 487             random_state=random_state)
#     488         # 2. Select the best couple on the full dataset amongst the 10
#     489         locations_full, covariances_full, supports_full, d = select_candidates(
#
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\covariance\robust_covariance.pyc in select_candidates(X, n_support, n_trials, select, n_iter, verbose, cov_computation_method, random_state)
#     272                     X, n_support, remaining_iterations=n_iter, verbose=verbose,
#     273                     cov_computation_method=cov_computation_method,
# --> 274                     random_state=random_state))
#     275     else:
#     276         # perform computations from every given initial estimates
#
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\covariance\robust_covariance.pyc in _c_step(X, n_support, random_state, remaining_iterations, initial_estimates, verbose, cov_computation_method)
#     144     if np.isinf(det):
#     145         raise ValueError(
# --> 146             "Singular covariance matrix. "
#     147             "Please check that the covariance matrix corresponding "
#     148             "to the dataset is full rank and that MinCovDet is used with "
#
# ValueError: Singular covariance matrix. Please check that the covariance matrix corresponding to the dataset is full rank and that MinCovDet is used with Gaussian-distributed data (or at least data drawn from a unimodal, symmetric distribution.

# %%
mcd_portfolio_ret = (weight * ret_df).sum(axis=1)

# %%
mcd_portfolio_ret = mcd_portfolio_ret[mcd_portfolio_ret != 0]

# %%
metric(mcd_portfolio_ret)
# Out:
# Annual return: 4.80%
# Sharpe ratio: 2.04
# Annual volatility: 2.31%
# Max drawdown: -3.97%

# %%
plt.figure(figsize=(16, 9))
plt.plot((1+equal_portfolio_ret).cumprod(), label='equal weight')
plt.plot((1+sample_portfolio_ret).cumprod(), label='sample covariance risk parity')
plt.plot((1+lw_portfolio_ret).cumprod(), label='lw covariance risk parity')
plt.plot((1+sc_portfolio_ret).cumprod(), label='shrunk covariance risk parity')
plt.plot((1+oas_portfolio_ret).cumprod(), label='oas covariance risk parity')
plt.plot((1+mcd_portfolio_ret).cumprod(), label='mcd covariance risk parity')
plt.legend()

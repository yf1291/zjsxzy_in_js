# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR = 'D:/Data/stocks/'

# %%
ind = pd.read_excel('D:/Data/index/000906.SH.xlsx')

# %%
comp = pd.read_excel('D:/Data/index-component/000906.SH.xlsx')

# %%
dic = {}
for code in comp['wind_code']:
    fname = '%s/%s.xlsx'%(DATA_DIR, code)
    temp = pd.read_excel(fname)
    dic[code] = temp['close']
df = pd.DataFrame(dic)

# %%
df.head()
# Out:
#             000001.SZ  000002.SZ  000006.SZ  000008.SZ  000009.SZ  000012.SZ  \
# 2010-01-04   8.007994   8.554429   3.690046   1.410065   5.714523   8.244930
# 2010-01-05   7.869518   8.360744   3.583858   1.410065   5.566916   8.104753
# 2010-01-06   7.734419   8.360744   3.593813   1.410065   5.561644   8.355372
# 2010-01-07   7.649982   8.296182   3.563947   1.410065   5.667078   7.913603
# 2010-01-08   7.633094   8.352674   3.650225   1.410065   5.941206   7.828648
#
#             000021.SZ  000025.SZ  000027.SZ  000028.SZ    ...      603799.SH  \
# 2010-01-04   8.096568      11.19   6.250165  26.625225    ...            NaN
# 2010-01-05   8.281986      11.21   6.245505  27.349787    ...            NaN
# 2010-01-06   8.226360      11.32   6.236183  27.774863    ...            NaN
# 2010-01-07   8.331430      11.05   6.096358  26.547938    ...            NaN
# 2010-01-08   8.319069      11.14   6.166271  26.035915    ...            NaN
#
#             603806.SH  603816.SH  603858.SH  603866.SH  603868.SH  603877.SH  \
# 2010-01-04        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-05        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-06        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-07        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-08        NaN        NaN        NaN        NaN        NaN        NaN
#
#             603883.SH  603888.SH  603993.SH
# 2010-01-04        NaN        NaN        NaN
# 2010-01-05        NaN        NaN        NaN
# 2010-01-06        NaN        NaN        NaN
# 2010-01-07        NaN        NaN        NaN
# 2010-01-08        NaN        NaN        NaN
#
# [5 rows x 800 columns]

# %%
mon_ret = df.pct_change().resample('M').last()

# %%
M = 12
E = np.ones(M)
corr = pd.Series(index=mon_ret.index)
for date in mon_ret.index:
    R = mon_ret[mon_ret.index <= date].iloc[-M:]
    if R.shape[0] == M:
        x = np.dot(R.T, E)
        y = np.dot(E, R)
        C = np.dot(R.T, R) - 1./M * np.dot(x.reshape(-1, 1), y.reshape(-1, 1).T)
        C = 1. / (M-1) * C
        d = np.diag(C)
        stddev = np.sqrt(d.real)
        C /= stddev[:, None]
        C /= stddev[None, :]
        corr.loc[date] = np.nanmean(C)
# Out:
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in divide
#   del sys.path[0]
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in divide

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(ind[ind.index >= '2010-01-01']['close'])
ax2 = ax1.twinx()
# ax2.plot(down.rolling(100).mean(), color='red')
ax2.plot(corr, color='red')

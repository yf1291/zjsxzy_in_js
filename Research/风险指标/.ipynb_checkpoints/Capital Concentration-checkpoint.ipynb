# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import empyrical
# %matplotlib inline

# %%
DATA_DIR = 'D:/Data/stocks/'
INDEX_FILE = 'D:/Data/index/000906.SH.xlsx'
COMP_FILE = u'D:/Data/index-component/000906.SH.xlsx'

# %%
ind_df = pd.read_excel(INDEX_FILE)

# %%
comp_df = pd.read_excel(COMP_FILE)

# %%
comp_df.head()
# Out:
#    i_weight sec_name  wind_code
# 0     0.560     平安银行  000001.SZ
# 1     1.180      万科A  000002.SZ
# 2     0.058     深振业A  000006.SZ
# 3     0.085     神州高铁  000008.SZ
# 4     0.121     中国宝安  000009.SZ

# %%
dic = {}
for code in comp_df['wind_code']:
    fname = '%s/%s.xlsx'%(DATA_DIR, code)
    temp = pd.read_excel(fname)
    dic[code] = temp['mkt_freeshares']
df = pd.DataFrame(dic)

# %%
df.tail()
# Out:
#                000001.SZ     000002.SZ     000006.SZ     000008.SZ  \
# 2018-03-30  8.295207e+10  1.846360e+11  6.531080e+09  1.309574e+10
# 2018-04-02  8.150612e+10  1.857452e+11  6.447202e+09  1.311488e+10
# 2018-04-03  8.036458e+10  1.865772e+11  6.304919e+09  1.280855e+10
# 2018-04-04  8.272376e+10  1.819183e+11  6.358275e+09  1.284684e+10
# 2018-04-09  8.386531e+10  1.753737e+11  6.393846e+09  1.271282e+10
#
#                000009.SZ     000012.SZ     000021.SZ     000025.SZ  \
# 2018-03-30  1.058783e+10  1.085012e+10  6.186011e+09  2.014730e+09
# 2018-04-02  1.058783e+10  1.087893e+10  6.327567e+09  1.988291e+09
# 2018-04-03  1.079714e+10  1.064839e+10  6.214322e+09  1.993147e+09
# 2018-04-04  1.091924e+10  1.082130e+10  6.001988e+09  1.982896e+09
# 2018-04-09  1.107623e+10  1.064839e+10  5.973677e+09  2.000701e+09
#
#                000027.SZ     000028.SZ      ...          603799.SH  \
# 2018-03-30  6.226136e+09  7.303039e+09      ...       3.934991e+10
# 2018-04-02  6.268781e+09  7.306723e+09      ...       3.689345e+10
# 2018-04-03  6.279442e+09  7.133572e+09      ...       3.740134e+10
# 2018-04-04  6.162169e+09  7.408649e+09      ...       3.710922e+10
# 2018-04-09  6.322087e+09  7.564607e+09      ...       3.738142e+10
#
#                603806.SH     603816.SH     603858.SH     603866.SH  \
# 2018-03-30  2.644770e+09  5.634684e+09  1.697202e+10  2.876610e+09
# 2018-04-02  2.698156e+09  5.579442e+09  1.713266e+10  2.889038e+09
# 2018-04-03  2.710421e+09  5.557167e+09  1.670648e+10  2.852940e+09
# 2018-04-04  2.636113e+09  5.704182e+09  1.692285e+10  2.907974e+09
# 2018-04-09  2.675071e+09  5.650722e+09  1.676221e+10  2.967744e+09
#
#                603868.SH     603877.SH     603883.SH     603888.SH  \
# 2018-03-30  2.438112e+09  1.597750e+09  5.990416e+09  3.847046e+09
# 2018-04-02  2.398436e+09  1.655500e+09  6.140155e+09  3.873516e+09
# 2018-04-03  2.391460e+09  1.647250e+09  6.163710e+09  3.751752e+09
# 2018-04-04  2.443780e+09  1.690700e+09  5.889468e+09  3.711164e+09
# 2018-04-09  2.462528e+09  1.720950e+09  5.856660e+09  3.757046e+09
#
#                603993.SH
# 2018-03-30  1.942539e+10
# 2018-04-02  1.882980e+10
# 2018-04-03  1.869236e+10
# 2018-04-04  1.823421e+10
# 2018-04-09  1.848619e+10
#
# [5 rows x 800 columns]

# %%
n = 80
mask = df.rank(axis=1, ascending=False)
mask[mask <= n] = 1
mask[mask > n] = 0
cap1 = (mask * df).sum(axis=1)

# %%
n = 800
mask = df.rank(axis=1, ascending=False)
mask[mask <= n] = 1
mask[mask > n] = 0
cap2 = (mask * df).sum(axis=1)

# %%
ratio = cap1 / cap2

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(ratio, color='red', label='captital concentration')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(ind_df[ind_df.index >= '2010-01-01']['close'], label=u'中证800', color='blue')
ax2.legend()

# %%
print ratio.corr(ind_df['close'])
# Out:
# -0.504524883801

# %%
rank_ratio = ratio.rolling(window=972).apply(lambda x: pd.Series(x).rank(pct=True).iloc[-1])

# %%
rank_ratio.tail()
# Out:
# 2018-03-16    0.949588
# 2018-03-19    0.956790
# 2018-03-20    0.953704
# 2018-03-21    0.958848
# 2018-03-22    0.948560
# dtype: float64

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(rank_ratio, color='red', label='captital concentration')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(ind_df[ind_df.index >= '2010-01-01']['close'], label=u'中证800', color='blue')
ax2.legend()

# %%
k = 0.01
[mm, mx] = rank_ratio.quantile([k, 1-k])

# %%
mm_index = rank_ratio[rank_ratio <= mm].index
mx_index = rank_ratio[rank_ratio >= mx].index

# %%
mm_index.shape, mx_index.shape
# Out:
# ((48L,), (11L,))

# %%
k = 20
ret_down = ind_df['close'].pct_change().rolling(k).apply(lambda x: empyrical.max_drawdown(x)).shift(-k)
ret_up = ind_df['close'].pct_change().rolling(k).apply(lambda x: -empyrical.max_drawdown(-x)).shift(-k)

# %%
ret_down.resample('M').last().quantile([0.4])
# Out:
# 0.4   -0.065814
# Name: close, dtype: float64

# %%
ret_up.quantile([0.95])
# Out:
# 0.95    0.181768
# Name: close, dtype: float64

# %% [markdown]
# # 验证概率

# %%
threshold = 0.1

# %%
down_right = ret_down.loc[mm_index].resample('M').last().dropna() < -threshold

# %%
up_right = ret_up.loc[mm_index].resample('M').last().dropna() > threshold

# %%
(down_right | up_right).sum() * 1.0 / down_right.shape[0]
# Out:
# 0.25

# %%
down_right = ret_down.loc[mx_index].resample('M').last().dropna() < -threshold

# %%
up_right = ret_up.loc[mx_index].resample('M').last().dropna() > threshold

# %%
(down_right | up_right).sum() * 1.0 / down_right.shape[0]
# Out:
# 1.0

# %%
ret_down.loc[mx_index].resample('M').last().dropna()
# Out:
# 2018-01-31   -0.12666
# Freq: M, Name: close, dtype: float64

# %% [markdown]
# # 月度数据

# %%
ind_df = pd.read_excel('D:/data/index/881001.WI.xlsx')
cap_df = pd.read_excel('D:/market cap.xlsx')

# %%
cap_df = cap_df.transpose()

# %%
cap_df = cap_df.replace([0.0], np.NAN)

# %%
mask = cap_df.rank(axis=1, ascending=False)

# %%
n = cap_df.shape[1] - cap_df.isnull().sum(axis=1)

# %%
cap = pd.Series(index=n.index)
for date in n.index:
    s = mask.loc[date]
    select = mask.loc[date] < n.loc[date]/10
#     print cap_df.loc[date].sum()
#     print (cap_df.loc[date] * select).sum()
    cap.loc[date] = (cap_df.loc[date] * select).sum()

# %%
ratio = cap / cap_df.sum(axis=1)

# %%
rank_ratio = ratio.rolling(60).apply(lambda x: pd.Series(x).rank(pct=True).iloc[-1])

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(rank_ratio, color='red', label=u'资金集中度')
ax1.legend()
ax2 = ax1.twinx()
ax2.plot(ind_df['close'], label=u'万得全A')
ax2.legend(loc='upper left')

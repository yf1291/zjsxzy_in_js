# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import empyrical
# %matplotlib inline

# %%
DATA_DIR = 'D:/Data/stocks/'
INDEX_FILE = 'D:/Data/index/000906.SH.xlsx'
COMP_FILE = u'D:/Data/index-component/000906.SH.xlsx'

# %%
ind_df = pd.read_excel(INDEX_FILE)

# %%
comp_df = pd.read_excel(COMP_FILE)

# %%
comp_df.head()
# Out:
#    i_weight sec_name  wind_code
# 0     0.560     平安银行  000001.SZ
# 1     1.180      万科A  000002.SZ
# 2     0.058     深振业A  000006.SZ
# 3     0.085     神州高铁  000008.SZ
# 4     0.121     中国宝安  000009.SZ

# %%
dic = {}
for code in comp_df['wind_code']:
    fname = '%s/%s.xlsx'%(DATA_DIR, code)
    temp = pd.read_excel(fname)
    dic[code] = temp['mkt_freeshares']
df = pd.DataFrame(dic)

# %%
df = df.loc[:df.index[-2]]

# %%
df.tail()
# Out:
#                000001.SZ     000002.SZ     000006.SZ     000008.SZ  \
# 2018-03-13  9.147559e+10  1.799484e+11  7.709687e+09  1.476894e+10
# 2018-03-14  9.071456e+10  1.811673e+11  7.346357e+09  1.472903e+10
# 2018-03-15  8.911640e+10  1.809457e+11  7.045059e+09  1.450949e+10
# 2018-03-16  8.858368e+10  1.807795e+11  7.036198e+09  1.454940e+10
# 2018-03-19  9.002963e+10  1.749622e+11  7.009612e+09  1.419016e+10
#
#                000009.SZ     000012.SZ     000021.SZ     000025.SZ  \
# 2018-03-13  1.119833e+10  1.172908e+10  6.412501e+09  2.306634e+09
# 2018-03-14  1.104134e+10  1.181553e+10  6.221400e+09  2.203577e+09
# 2018-03-15  1.091924e+10  1.182994e+10  6.249711e+09  2.251598e+09
# 2018-03-16  1.111111e+10  1.165703e+10  6.235556e+09  2.223001e+09
# 2018-03-19  1.111111e+10  1.139767e+10  6.249711e+09  2.162570e+09
#
#                000027.SZ     000028.SZ      ...          603799.SH  \
# 2018-03-13  6.300764e+09  7.368124e+09      ...       3.415313e+10
# 2018-03-14  6.268781e+09  7.337423e+09      ...       3.415313e+10
# 2018-03-15  6.300764e+09  7.209709e+09      ...       3.509637e+10
# 2018-03-16  6.290103e+09  7.077083e+09      ...       3.423550e+10
# 2018-03-19  6.354070e+09  7.284618e+09      ...       4.270211e+10
#
#                603806.SH     603816.SH     603858.SH     603866.SH  \
# 2018-03-13  2.274150e+09  5.755860e+09  1.698186e+10  2.564154e+09
# 2018-03-14  2.217198e+09  5.703291e+09  1.735231e+10  2.572439e+09
# 2018-03-15  2.139953e+09  5.826249e+09  1.726052e+10  2.570664e+09
# 2018-03-16  2.254511e+09  5.819121e+09  1.699825e+10  2.604987e+09
# 2018-03-19  2.205415e+09  5.893074e+09  1.713266e+10  2.643452e+09
#
#                603868.SH     603877.SH     603883.SH     603888.SH  \
# 2018-03-13  2.776448e+09  1.698400e+09  5.759077e+09  4.092339e+09
# 2018-03-14  2.731104e+09  1.642850e+09  5.557181e+09  4.094104e+09
# 2018-03-15  2.755520e+09  1.652750e+09  5.869279e+09  4.127633e+09
# 2018-03-16  2.745492e+09  1.642300e+09  5.752347e+09  4.087045e+09
# 2018-03-19  2.700148e+09  1.648900e+09  5.838994e+09  4.081751e+09
#
#                603993.SH
# 2018-03-13  2.130380e+10
# 2018-03-14  2.091437e+10
# 2018-03-15  2.167031e+10
# 2018-03-16  2.114344e+10
# 2018-03-19  2.219718e+10
#
# [5 rows x 800 columns]

# %%
n = 80
mask = df.rank(axis=1, ascending=False)
mask[mask <= n] = 1
mask[mask > n] = 0
cap1 = (mask * df).sum(axis=1)

# %%
n = 800
mask = df.rank(axis=1, ascending=False)
mask[mask <= n] = 1
mask[mask > n] = 0
cap2 = (mask * df).sum(axis=1)

# %%
ratio = cap1 / cap2

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(ratio, color='red', label='captital concentration')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(ind_df[ind_df.index >= '2010-01-01']['close'], label=u'中证800', color='blue')
ax2.legend()

# %%
print ratio.corr(ind_df['close'])
# Out:
# -0.504524883801

# %%
rank_ratio = ratio.rolling(window=972).apply(lambda x: pd.Series(x).rank(pct=True).iloc[-1])

# %%
fig, ax1 = plt.subplots(figsize=(16, 9))
ax1.plot(rank_ratio, color='red', label='captital concentration')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(ind_df[ind_df.index >= '2010-01-01']['close'], label=u'中证800', color='blue')
ax2.legend()

# %%
k = 0.01
[mm, mx] = rank_ratio.quantile([k, 1-k])

# %%
mm_index = rank_ratio[rank_ratio <= mm].index
mx_index = rank_ratio[rank_ratio >= mx].index

# %%
mm_index.shape, mx_index.shape
# Out:
# ((48L,), (11L,))

# %%
k = 20
ret_down = ind_df['close'].pct_change().rolling(k).apply(lambda x: empyrical.max_drawdown(x)).shift(-k)
ret_up = ind_df['close'].pct_change().rolling(k).apply(lambda x: -empyrical.max_drawdown(-x)).shift(-k)

# %%
ret_down.resample('M').last().quantile([0.4])
# Out:
# 0.4   -0.065814
# Name: close, dtype: float64

# %%
ret_up.quantile([0.95])
# Out:
# 0.95    0.181768
# Name: close, dtype: float64

# %% [markdown]
# # 验证概率

# %%
threshold = 0.1

# %%
down_right = ret_down.loc[mm_index].resample('M').last().dropna() < -threshold

# %%
up_right = ret_up.loc[mm_index].resample('M').last().dropna() > threshold

# %%
(down_right | up_right).sum() * 1.0 / down_right.shape[0]
# Out:
# 0.25

# %%
down_right = ret_down.loc[mx_index].resample('M').last().dropna() < -threshold

# %%
up_right = ret_up.loc[mx_index].resample('M').last().dropna() > threshold

# %%
(down_right | up_right).sum() * 1.0 / down_right.shape[0]
# Out:
# 1.0

# %%
ret_down.loc[mx_index].resample('M').last().dropna()
# Out:
# 2018-01-31   -0.12666
# Freq: M, Name: close, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from adjustText import adjust_text
from WindPy import w
# %matplotlib inline

# %%
w.start()
# Out:
# .ErrorCode=0
# .Data=[Already conntected!]

# %%
start_date, end_date = '2010-01-01', '2020-07-01'

# %%
data = w.wset("sectorconstituent","sectorid=a39901011g000000;field=wind_code,sec_name") ## 申万一级行业
# data = w.wset("sectorconstituent","sectorid=a39901011h000000;field=wind_code,sec_name") ## 申万一级行业

# %%
df = pd.DataFrame(data.Data, index=data.Fields)
df = df.T

# %%
data = w.wsd(df['wind_code'].tolist(), 'close', start_date, end_date, 'Period=M')

# %%
prices = pd.DataFrame(data.Data, index=data.Codes, columns=data.Times)
prices = prices.T

# %%
data = w.wsd('000906.SH', 'close', start_date, end_date, 'Period=M')

# %%
bench = pd.DataFrame(data.Data, index=data.Codes, columns=data.Times)
bench = bench.T

# %%
returns = prices.pct_change()
bench_ret = bench.pct_change()

# %% [markdown]
# # 与利率的敏感性

# %%
data = w.wsd('S0059749', 'close', start_date, end_date, 'Period=M')

# %%
bond = pd.DataFrame(data.Data, index=['rate'], columns=data.Times)
bond = bond.T

# %%
bond_chg = bond.pct_change()

# %%
correlations = pd.DataFrame(index=returns.columns, columns=['利率敏感性'])
for col in returns:
    excess_return = returns[col] - bench_ret['000906.SH']
    correlations.loc[col, '利率敏感性'] = excess_return.corr(bond_chg['rate'])

# %%
data = w.wss(correlations.index.tolist(), 'sec_name')

# %%
correlations['证券名称'] = data.Data[0]

# %%
correlations = correlations.sort_values('利率敏感性')

# %%
correlations
# Out:
#                 利率敏感性      证券名称
# 801160.SI    -0.16333  公用事业(申万)
# 801770.SI   -0.131352    通信(申万)
# 801230.SI   -0.115414    综合(申万)
# 801150.SI  -0.0993871  医药生物(申万)
# 801720.SI  -0.0875224  建筑装饰(申万)
# 801130.SI  -0.0793463  纺织服装(申万)
# 801730.SI  -0.0789601  电气设备(申万)
# 801750.SI  -0.0728361   计算机(申万)
# 801760.SI  -0.0726991    传媒(申万)
# 801740.SI   -0.068455  国防军工(申万)
# 801010.SI  -0.0630129  农林牧渔(申万)
# 801710.SI  -0.0616082  建筑材料(申万)
# 801180.SI   -0.061152   房地产(申万)
# 801030.SI  -0.0212128    化工(申万)
# 801050.SI   -0.015754  有色金属(申万)
# 801880.SI  -0.0155684    汽车(申万)
# 801210.SI  -0.0143608  休闲服务(申万)
# 801140.SI -0.00443997  轻工制造(申万)
# 801080.SI  0.00597461    电子(申万)
# 801200.SI  0.00609661  商业贸易(申万)
# 801780.SI   0.0130091    银行(申万)
# 801890.SI   0.0247715  机械设备(申万)
# 801170.SI   0.0268195  交通运输(申万)
# 801040.SI   0.0287793    钢铁(申万)
# 801120.SI   0.0335482  食品饮料(申万)
# 801790.SI   0.0384308  非银金融(申万)
# 801110.SI   0.0940682  家用电器(申万)
# 801020.SI    0.100743    采掘(申万)

# %%
fig, ax = plt.subplots(figsize=(16, 9))

x = np.arange(correlations.shape[0])

ax.bar(x, correlations['利率敏感性'], color='blue')

ax.set_xticks(x)
_ = ax.set_xticklabels([x.rstrip('(申万)') for x in correlations['证券名称']], rotation=60, fontsize=15)

ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)

_ = ax.set_title('申万一级行业对利率变化的敏感性', fontsize=25, y=1.02)
fig.savefig(u'C:/Users/zhangyang01/Desktop/申万一级行业对利率变化的敏感性.png', format='png', dpi=400, bbox_inches='tight')

# %%
data = w.wsd('000931.CSI,000933.SH', 'close', '2010-01-01', '2020-07-29', 'Period=M')

# %%
style = pd.DataFrame(data.Data, columns=data.Times, index=data.Codes)
style = style.T

# %%
data = w.wsd('S0059749', 'close', start_date, end_date, 'Period=M')

# %%
bond = pd.DataFrame(data.Data, index=['rate'], columns=data.Times)
bond = bond.T
bond.index = pd.to_datetime(bond.index)

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot(style['000931.CSI'] / style['000933.SH'], color='blue', label='家电/成长')
axx = ax.twinx()
axx.plot(bond[bond.index >= '2010-01-01']['rate'], color='red', label='国债10Y收益率（右轴）')

ax.legend(fontsize=15, loc='upper left')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
axx.legend(fontsize=15, loc='upper right')
axx.yaxis.set_tick_params(labelsize=15)

# _ = ax.set_title('申万一级行业对利率变化的敏感性', fontsize=25, y=1.02)
# fig.savefig(u'C:/Users/zhangyang01/Desktop/申万一级行业对利率变化的敏感性.png', format='png', dpi=400, bbox_inches='tight')

# %% [markdown]
# # 对PMI的敏感性

# %%
pmi = pd.read_excel('./data/pmi.xlsx', skiprows=1, index_col=0)

# %%
pmi.index = returns.index[:-1]

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot(pmi['PMI'], color='blue')
ax.axhline(50, color='black')

# %%
for i in range(1, 5):
    dates = pmi[pmi['阶段'] == i].index
    if i == 1:
        correlations['trough to 50'] = returns.loc[dates].median()
    elif i == 2:
        correlations['50 to peak'] = returns.loc[dates].median()
    elif i == 3:
        correlations['peak to 50'] = returns.loc[dates].median()
    else:
        correlations['50 to trough'] = returns.loc[dates].median()

# %%
correlations.sort_values('peak to 50', ascending=False)
# Out:
#                 利率敏感性      证券名称  trough to 50  50 to peak  peak to 50  \
# 801210.SI  -0.0184057  休闲服务(申万)     -0.002860    0.015301    0.010647
# 801150.SI   -0.100558  医药生物(申万)      0.017559    0.021974    0.007710
# 801710.SI  -0.0636004  建筑材料(申万)      0.022311    0.009786    0.003044
# 801120.SI   0.0328698  食品饮料(申万)      0.012428    0.011273    0.002411
# 801200.SI  0.00685909  商业贸易(申万)     -0.013200    0.005432    0.001739
# 801720.SI  -0.0866782  建筑装饰(申万)     -0.005998   -0.001750   -0.000488
# 801890.SI   0.0250823  机械设备(申万)     -0.006642    0.013234   -0.000815
# 801040.SI   0.0299839    钢铁(申万)     -0.005535    0.011633   -0.001078
# 801160.SI   -0.163081  公用事业(申万)     -0.011561    0.009724   -0.005321
# 801080.SI  0.00492735    电子(申万)      0.034073    0.032826   -0.005827
# 801010.SI   -0.063589  农林牧渔(申万)      0.003932    0.015076   -0.006329
# 801170.SI   0.0277703  交通运输(申万)     -0.011100    0.002751   -0.008382
# 801130.SI  -0.0789493  纺织服装(申万)     -0.014000   -0.004580   -0.008589
# 801030.SI  -0.0223406    化工(申万)     -0.001852    0.016571   -0.008692
# 801140.SI -0.00476652  轻工制造(申万)     -0.004863    0.019415   -0.010773
# 801730.SI  -0.0808644  电气设备(申万)     -0.009813    0.020441   -0.010789
# 801050.SI  -0.0159978  有色金属(申万)      0.012721    0.027332   -0.011448
# 801110.SI   0.0937863  家用电器(申万)      0.020217    0.022828   -0.011513
# 801780.SI    0.014902    银行(申万)      0.013548    0.002614   -0.012033
# 801020.SI    0.101361    采掘(申万)     -0.005825   -0.007329   -0.014235
# 801750.SI  -0.0727633   计算机(申万)      0.005402    0.024666   -0.015196
# 801760.SI  -0.0726765    传媒(申万)     -0.004528    0.018015   -0.017688
# 801880.SI  -0.0152516    汽车(申万)      0.003730    0.017523   -0.018062
# 801180.SI   -0.059669   房地产(申万)      0.001889   -0.003348   -0.018702
# 801790.SI   0.0388845  非银金融(申万)     -0.007882    0.005924   -0.021709
# 801770.SI   -0.131373    通信(申万)     -0.006686    0.022569   -0.022360
# 801230.SI   -0.114371    综合(申万)     -0.003139    0.015708   -0.024152
# 801740.SI  -0.0656171  国防军工(申万)     -0.008143    0.015842   -0.025931
#
#            50 to trough
# 801210.SI      0.008053
# 801150.SI      0.012533
# 801710.SI      0.021002
# 801120.SI      0.032039
# 801200.SI      0.004278
# 801720.SI     -0.021398
# 801890.SI      0.008159
# 801040.SI      0.004693
# 801160.SI     -0.008030
# 801080.SI      0.031305
# 801010.SI      0.029706
# 801170.SI      0.008141
# 801130.SI     -0.010718
# 801030.SI      0.010794
# 801140.SI     -0.002557
# 801730.SI      0.012977
# 801050.SI      0.031288
# 801110.SI      0.060008
# 801780.SI     -0.001728
# 801020.SI      0.022386
# 801750.SI      0.027909
# 801760.SI      0.016702
# 801880.SI      0.007404
# 801180.SI      0.015574
# 801790.SI     -0.013240
# 801770.SI      0.018193
# 801230.SI     -0.005025
# 801740.SI     -0.014883

# %% [markdown]
# # OECD综合领先指标

# %%
oecd = pd.read_excel('./data/OECD综合领先指标.xlsx', index_col=0)

# %%
oecd.index = returns.index[:-1]

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.plot(oecd['OECD综合领先指标:中国:同比'], color='blue')
ax.axhline(0, color='black')

# %%
for i in range(1, 5):
    dates = oecd[oecd['阶段'] == i].index
    if i == 1:
        correlations['trough to 50'] = returns.loc[dates].median()
    elif i == 2:
        correlations['50 to peak'] = returns.loc[dates].median()
    elif i == 3:
        correlations['peak to 50'] = returns.loc[dates].median()
    else:
        correlations['50 to trough'] = returns.loc[dates].median()

# %%
correlations.sort_values('50 to peak', ascending=False)
# Out:
#                 利率敏感性      证券名称  trough to 50  50 to peak  peak to 50  \
# 801110.SI   0.0937863  家用电器(申万)      0.022347    0.027563    0.023606
# 801150.SI   -0.100558  医药生物(申万)      0.016660    0.021133    0.020736
# 801160.SI   -0.163081  公用事业(申万)     -0.006912    0.020201    0.004536
# 801140.SI -0.00476652  轻工制造(申万)     -0.010173    0.017847    0.019927
# 801080.SI  0.00492735    电子(申万)      0.033497    0.013370    0.039120
# 801050.SI  -0.0159978  有色金属(申万)      0.019505    0.012721    0.002082
# 801210.SI  -0.0184057  休闲服务(申万)      0.000583    0.010850    0.025501
# 801200.SI  0.00685909  商业贸易(申万)     -0.008448    0.008385    0.005323
# 801030.SI  -0.0223406    化工(申万)     -0.003134    0.007984    0.005825
# 801740.SI  -0.0656171  国防军工(申万)     -0.000618    0.007695   -0.012494
# 801880.SI  -0.0152516    汽车(申万)      0.008644    0.007570   -0.009288
# 801120.SI   0.0328698  食品饮料(申万)      0.017458    0.006950    0.015942
# 801790.SI   0.0388845  非银金融(申万)     -0.004122    0.004895   -0.000813
# 801770.SI   -0.131373    通信(申万)     -0.006822    0.004014   -0.011267
# 801760.SI  -0.0726765    传媒(申万)     -0.000126    0.003594   -0.010885
# 801040.SI   0.0299839    钢铁(申万)     -0.003384    0.002823   -0.014919
# 801170.SI   0.0277703  交通运输(申万)     -0.007117    0.002473    0.002998
# 801710.SI  -0.0636004  建筑材料(申万)      0.019390    0.001991    0.005240
# 801750.SI  -0.0727633   计算机(申万)      0.011929    0.000546    0.014688
# 801890.SI   0.0250823  机械设备(申万)      0.007154   -0.001670    0.011535
# 801130.SI  -0.0789493  纺织服装(申万)     -0.017087   -0.003168   -0.002144
# 801180.SI   -0.059669   房地产(申万)      0.007135   -0.003554   -0.012611
# 801730.SI  -0.0808644  电气设备(申万)     -0.002492   -0.004245    0.026724
# 801020.SI    0.101361    采掘(申万)     -0.004881   -0.004255   -0.009684
# 801720.SI  -0.0866782  建筑装饰(申万)     -0.011708   -0.005855   -0.006192
# 801230.SI   -0.114371    综合(申万)     -0.007312   -0.005969    0.013888
# 801010.SI   -0.063589  农林牧渔(申万)      0.008252   -0.006474   -0.000941
# 801780.SI    0.014902    银行(申万)      0.002581   -0.007875   -0.000390
#
#            50 to trough
# 801110.SI      0.001169
# 801150.SI      0.017269
# 801160.SI     -0.006114
# 801140.SI     -0.006031
# 801080.SI      0.007231
# 801050.SI     -0.009406
# 801210.SI      0.001448
# 801200.SI     -0.000354
# 801030.SI      0.003212
# 801740.SI      0.000845
# 801880.SI      0.006065
# 801120.SI     -0.004158
# 801790.SI     -0.014220
# 801770.SI      0.005971
# 801760.SI     -0.013522
# 801040.SI      0.013456
# 801170.SI     -0.007657
# 801710.SI      0.014615
# 801750.SI      0.003691
# 801890.SI      0.005170
# 801130.SI     -0.009209
# 801180.SI     -0.004511
# 801730.SI     -0.006361
# 801020.SI     -0.013078
# 801720.SI     -0.000538
# 801230.SI     -0.000713
# 801010.SI      0.002902
# 801780.SI     -0.002330

# %%
correlations.median()
# Out:
# 利率敏感性          -0.020373
# trough to 50   -0.000372
# 50 to peak      0.003804
# peak to 50      0.003767
# 50 to trough   -0.000446
# dtype: float64

# %% [markdown]
# # PPI敏感性

# %%
data = w.edb('M0001227', start_date, end_date)

# %%
ppi = pd.DataFrame(data.Data, columns=data.Times, index=['ppi'])
ppi = ppi.T

# %%
for col in returns:
    excess_return = returns[col] - bench_ret['000906.SH']
    correlations.loc[col, 'ppi敏感性'] = excess_return.corr(ppi['ppi']/100)

# %%
correlations = correlations.sort_values('ppi敏感性')

# %%
fig, ax = plt.subplots(figsize=(16, 9))

x = np.arange(correlations.shape[0])

ax.bar(x, correlations['ppi敏感性'], color='blue')

ax.set_xticks(x)
_ = ax.set_xticklabels([x.rstrip('(申万)') for x in correlations['证券名称']], rotation=60, fontsize=15)

ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)

_ = ax.set_title('申万一级行业对PPI变化的敏感性', fontsize=25, y=1.02)

# %% [markdown]
# # ROE与利率敏感性

# %%
data = w.wss(correlations.index.tolist(), "west_avgroe_FY1", "tradeDate=20200726")

# %%
correlations['roe'] = data.Data[0]

# %%
data = w.wss(correlations.index.tolist(), "mkt_cap_ard", "tradeDate=20200726")

# %%
correlations['cap'] = data.Data[0]

# %%
correlations.head()
# Out:
#                利率敏感性      证券名称    ppi敏感性      roe           cap
# 801180.SI -0.0609643   房地产(申万) -0.183673  13.6149  2.238266e+12
# 801880.SI -0.0151077    汽车(申万) -0.163086   5.8372  1.917488e+12
# 801170.SI  0.0268724  交通运输(申万) -0.147698   4.2232  2.369117e+12
# 801160.SI  -0.163354  公用事业(申万) -0.140492   7.9143  2.256146e+12
# 801760.SI -0.0725872    传媒(申万) -0.110461   3.2178  1.979430e+12

# %%
fig, ax = plt.subplots(figsize=(16, 9))

ax.scatter(correlations['roe'], correlations['利率敏感性'], color='blue', s=correlations['cap']/1e10)
ax.axhline(0, color='black', linestyle='--', linewidth=1)
ax.axvline(correlations['roe'].median(), linestyle='--', linewidth=1, color='black')

texts = [ax.text(correlations['roe'][i], correlations['利率敏感性'][i], correlations['证券名称'][i].rstrip('(申万)'), fontsize=10) for i in range(correlations.shape[0])]
adjust_text(texts)

ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
vals = ax.get_yticks()
ax.set_yticklabels(['{:2.0f}%'.format(x*100) for x in vals])
vals = ax.get_xticks()
ax.set_xticklabels(['{:2.0f}%'.format(x) for x in vals])
ax.set_ylabel('超额收益对利率敏感性', fontsize=15)
ax.set_xlabel('ROE(fy1)', fontsize=15)

fig.savefig(u'C:/Users/zhangyang01/Desktop/申万二级行业ROE与利率敏感性.png', format='png', dpi=400, bbox_inches='tight')

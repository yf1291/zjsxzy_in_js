# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.cluster
import alphalens
# %matplotlib inline
# Out:
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
DATA_DIR = 'D:/Data/index/'

# %%
fname = '%s/881001.WI.xlsx'%(DATA_DIR)
df = pd.read_excel(fname)

# %%
files = [f for f in os.listdir(DATA_DIR) if f.startswith('CI')]

# %%
dic = {}
for f in files:
    fname = '%s/%s'%(DATA_DIR, f)
    temp = pd.read_excel(fname)
    dic[f.rstrip('.xlsx')] = temp['close']
idf = pd.DataFrame(dic)

# %%
idf = idf.dropna()

# %%
ret_df = idf.resample('M').last().pct_change()

# %%
rret_df = ret_df.subtract(df['close'].resample('M').last().pct_change(), axis='index')

# %%
rret_df = rret_df.dropna()

# %%
plt.figure(figsize=(16, 9))
(1+rret_df['CI005027.WI']).cumprod().plot()

# %%
def transition_matrix(labels, n):
    M = [[0]*n for _ in range(n)]
    for (i,j) in zip(labels, labels[1:]):
        M[i][j] += 1
    for row in M:
        m = sum(row)
        if m > 0:
            row[:] = [x*1./m for x in row]
    Mdf = pd.DataFrame(M, index=range(n), columns=range(n))
    return Mdf

# %%
rret_df.shape
# Out:
# (157, 29)

# %% [markdown]
# # 对收益率百分位进行聚类

# %%
affprop = sklearn.cluster.AffinityPropagation()
affprop.fit(rret_df.rank(pct=True, axis=1))
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#           damping=0.5, max_iter=200, preference=None, verbose=False)

# %%
# K = 10
# kmeans = sklearn.cluster.KMeans(n_clusters=K)
# kmeans.fit(rret_df)

# %%
# pd.DataFrame(kmeans.cluster_centers_, columns=rret_df.columns).to_excel('C:/Users/zhangyang01/Desktop/temp2.xlsx')

# %%
# kmeans.labels_

# %%
affprop.labels_
# Out:
# array([ 1,  0, 14, 14, 12, 11,  1,  7,  0, 15,  1,  0,  5, 14,  0,  0,  7,
#         8, 12, 15, 15,  3,  1,  1,  7,  2,  2,  2,  9,  5, 10, 10,  3,  1,
#        13, 13, 13,  7, 16, 14, 13, 11, 13,  8,  3, 15,  2, 12,  4,  7,  4,
#         5, 10,  1,  3, 13,  5,  4,  7,  5, 13, 13,  5,  6,  7, 16,  9,  7,
#         6, 10, 13, 10,  8, 13, 14, 14, 15,  9,  7, 11,  3, 11,  6,  1, 10,
#        13, 11,  9, 16, 11, 11, 12,  0,  8, 10, 10, 12, 13, 12,  5, 12, 11,
#        12,  4, 12,  8, 13, 16, 12,  6,  8, 16, 13, 12, 10, 13, 13,  8, 10,
#        10, 13, 12, 13,  8, 13, 14, 15, 14, 11, 13, 13, 16, 14, 14, 13, 14,
#         5, 13, 14, 10,  8,  3,  8, 14, 10,  2, 16, 14,  1,  9, 10,  6, 13,
#        16,  1, 16,  1], dtype=int64)

# %% [markdown]
# # 计算转移概率矩阵

# %%
# tran = transition_matrix(kmeans.labels_, K)

# %%
tran = transition_matrix(affprop.labels_, affprop.labels_.max()+1)

# %%
tran
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.166667  0.000000  0.000000  0.000000  0.000000  0.166667  0.000000
# 1   0.200000  0.100000  0.000000  0.100000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.400000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.333333  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.250000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.125000  0.000000  0.125000
# 6   0.000000  0.200000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.111111  0.000000  0.111111  0.000000  0.111111  0.111111  0.111111
# 8   0.000000  0.000000  0.000000  0.200000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.200000  0.000000
# 10  0.000000  0.071429  0.071429  0.071429  0.000000  0.000000  0.071429
# 11  0.000000  0.111111  0.000000  0.111111  0.000000  0.000000  0.111111
# 12  0.083333  0.000000  0.000000  0.000000  0.166667  0.083333  0.083333
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.083333  0.000000
# 14  0.071429  0.071429  0.000000  0.000000  0.000000  0.071429  0.000000
# 15  0.000000  0.166667  0.166667  0.166667  0.000000  0.000000  0.000000
# 16  0.000000  0.222222  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           7         8         9         10        11        12        13  \
# 0   0.166667  0.166667  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.200000  0.000000  0.100000  0.100000  0.000000  0.000000  0.100000
# 2   0.000000  0.000000  0.200000  0.000000  0.000000  0.200000  0.000000
# 3   0.000000  0.166667  0.000000  0.000000  0.166667  0.000000  0.166667
# 4   0.500000  0.000000  0.000000  0.000000  0.000000  0.250000  0.000000
# 5   0.000000  0.000000  0.000000  0.250000  0.000000  0.125000  0.250000
# 6   0.200000  0.200000  0.000000  0.200000  0.000000  0.000000  0.200000
# 7   0.000000  0.111111  0.000000  0.000000  0.111111  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.200000  0.000000  0.100000  0.300000
# 9   0.400000  0.000000  0.000000  0.200000  0.000000  0.000000  0.000000
# 10  0.000000  0.142857  0.000000  0.214286  0.000000  0.071429  0.285714
# 11  0.000000  0.000000  0.111111  0.000000  0.111111  0.222222  0.222222
# 12  0.000000  0.083333  0.000000  0.083333  0.166667  0.000000  0.166667
# 13  0.041667  0.125000  0.000000  0.041667  0.083333  0.125000  0.208333
# 14  0.000000  0.000000  0.000000  0.142857  0.071429  0.071429  0.142857
# 15  0.000000  0.000000  0.166667  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.111111  0.000000  0.111111  0.111111  0.111111
#
#           14        15        16
# 0   0.166667  0.166667  0.000000
# 1   0.000000  0.000000  0.100000
# 2   0.000000  0.000000  0.200000
# 3   0.000000  0.166667  0.000000
# 4   0.000000  0.000000  0.000000
# 5   0.125000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.222222
# 8   0.100000  0.000000  0.100000
# 9   0.000000  0.000000  0.200000
# 10  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000
# 12  0.000000  0.083333  0.000000
# 13  0.166667  0.000000  0.125000
# 14  0.214286  0.142857  0.000000
# 15  0.166667  0.166667  0.000000
# 16  0.333333  0.000000  0.000000

# %% [markdown]
# # 计算下期预期收益

# %%
# label = kmeans.labels_[-1]
label = affprop.labels_[-1]

# %%
prob = tran.loc[label].values

# %%
# pred = kmeans.cluster_centers_.T.dot(prob)
pred = affprop.cluster_centers_.T.dot(prob)

# %%
pd.Series(pred, index=rret_df.columns).sort_values(ascending=False)
# Out:
# CI005003.WI    0.706897
# CI005008.WI    0.679310
# CI005010.WI    0.655172
# CI005014.WI    0.648276
# CI005006.WI    0.637931
# CI005022.WI    0.627586
# CI005025.WI    0.620690
# CI005015.WI    0.596552
# CI005019.WI    0.589655
# CI005012.WI    0.586207
# CI005016.WI    0.562069
# CI005023.WI    0.558621
# CI005013.WI    0.555172
# CI005002.WI    0.541379
# CI005001.WI    0.534483
# CI005018.WI    0.531034
# CI005029.WI    0.531034
# CI005020.WI    0.520690
# CI005007.WI    0.510345
# CI005011.WI    0.489655
# CI005026.WI    0.451724
# CI005005.WI    0.396552
# CI005028.WI    0.389655
# CI005024.WI    0.389655
# CI005009.WI    0.375862
# CI005017.WI    0.362069
# CI005004.WI    0.358621
# CI005021.WI    0.306897
# CI005027.WI    0.286207
# dtype: float64

# %% [markdown]
# # 滚动计算历史预测

# %%
# K = 10
pred_df = pd.DataFrame(index=rret_df.index, columns=rret_df.columns)
for i, date in enumerate(rret_df.index):
    past_return = rret_df[rret_df.index <= date]
    if past_return.shape[0] >= 60:
        past_return = past_return.rank(pct=True, axis=1)
#         kmeans = sklearn.cluster.KMeans(n_clusters=K)
#         kmeans.fit(past_return)
        affprop = sklearn.cluster.AffinityPropagation()
        affprop.fit(past_return)
        label = affprop.labels_[-1]
        tran = transition_matrix(affprop.labels_, affprop.labels_.max()+1)
        prob = tran.loc[label].values
        pred = affprop.cluster_centers_.T.dot(prob)
        pred_df.loc[date] = pred

# %%
# plt.figure(figsize=(16, 9))
# plt.scatter(pred_df['CI005021.WI'], rret_df['CI005021.WI'].shift(-1))

# %%
pred_df.tail()
# Out:
#            CI005001.WI CI005002.WI CI005003.WI CI005004.WI CI005005.WI  \
# 2017-09-30    0.514243    0.335832    0.373313    0.541229    0.422789
# 2017-10-31    0.665025    0.541872    0.394089    0.571429     0.53202
# 2017-11-30    0.530172    0.465517    0.551724    0.418103    0.327586
# 2017-12-31    0.689655    0.543103    0.362069    0.586207    0.543103
# 2018-01-31    0.534483    0.541379    0.706897    0.358621    0.396552
#
#            CI005006.WI CI005007.WI CI005008.WI CI005009.WI CI005010.WI  \
# 2017-09-30    0.512744    0.392804    0.475262    0.596702    0.596702
# 2017-10-31     0.53202    0.334975    0.359606    0.512315    0.438424
# 2017-11-30    0.573276    0.612069    0.616379    0.327586    0.564655
# 2017-12-31    0.474138    0.366379    0.366379    0.482759    0.431034
# 2018-01-31    0.637931    0.510345     0.67931    0.375862    0.655172
#
#                ...     CI005020.WI CI005021.WI CI005022.WI CI005023.WI  \
# 2017-09-30     ...        0.484258    0.572714    0.436282    0.509745
# 2017-10-31     ...         0.53202    0.605911    0.477833    0.605911
# 2017-11-30     ...        0.534483    0.491379    0.564655    0.586207
# 2017-12-31     ...        0.478448    0.655172    0.534483    0.642241
# 2018-01-31     ...         0.52069    0.306897    0.627586    0.558621
#
#            CI005024.WI CI005025.WI CI005026.WI CI005027.WI CI005028.WI  \
# 2017-09-30    0.514243    0.631184    0.529235    0.554723    0.433283
# 2017-10-31    0.596059    0.591133    0.374384    0.448276    0.344828
# 2017-11-30    0.366379    0.659483    0.435345    0.396552    0.439655
# 2017-12-31     0.62069    0.538793    0.422414    0.456897    0.392241
# 2018-01-31    0.389655     0.62069    0.451724    0.286207    0.389655
#
#            CI005029.WI
# 2017-09-30    0.578711
# 2017-10-31     0.62069
# 2017-11-30    0.517241
# 2017-12-31    0.547414
# 2018-01-31    0.531034
#
# [5 rows x 29 columns]

# %%
pred_df.iloc[-1].sort_values(ascending=False)
# Out:
# CI005003.WI    0.706897
# CI005008.WI     0.67931
# CI005010.WI    0.655172
# CI005014.WI    0.648276
# CI005006.WI    0.637931
# CI005022.WI    0.627586
# CI005025.WI     0.62069
# CI005015.WI    0.596552
# CI005019.WI    0.589655
# CI005012.WI    0.586207
# CI005016.WI    0.562069
# CI005023.WI    0.558621
# CI005013.WI    0.555172
# CI005002.WI    0.541379
# CI005001.WI    0.534483
# CI005018.WI    0.531034
# CI005029.WI    0.531034
# CI005020.WI     0.52069
# CI005007.WI    0.510345
# CI005011.WI    0.489655
# CI005026.WI    0.451724
# CI005005.WI    0.396552
# CI005028.WI    0.389655
# CI005024.WI    0.389655
# CI005009.WI    0.375862
# CI005017.WI    0.362069
# CI005004.WI    0.358621
# CI005021.WI    0.306897
# CI005027.WI    0.286207
# Name: 2018-01-31 00:00:00, dtype: object

# %% [markdown]
# # 验证因子

# %%
pred_df = pred_df.dropna()
pricing = idf[idf.index >= pred_df.index[0]].resample('M').last()

# %%
factor_df = pred_df.stack()
factor_df.index = factor_df.index.set_names(['date', 'asset'])

# %%
factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor_df, pricing, quantiles=5, periods=(1,2,3))
# Out:
# Dropped 3.1% entries from factor data (3.1% after in forward returns computation and 0.0% in binning phase). Set max_loss=0 to see potentially suppressed Exceptions.

# %%
factor_data.head()
# Out:
#                                1         2         3    factor  \
# date       asset
# 2009-12-31 CI005001.WI -0.085843 -0.061246 -0.043570  0.363985
#            CI005002.WI -0.164913 -0.155105 -0.128434  0.559387
#            CI005003.WI -0.138576 -0.118718 -0.097909  0.750958
#            CI005004.WI -0.052817 -0.004012  0.009713  0.455939
#            CI005005.WI -0.153171 -0.127838 -0.135772   0.43295
#
#                         factor_quantile
# date       asset
# 2009-12-31 CI005001.WI                1
#            CI005002.WI                4
#            CI005003.WI                5
#            CI005004.WI                2
#            CI005005.WI                1

# %%
mean_return_by_q, std_err_by_q = alphalens.performance.mean_return_by_quantile(factor_data, by_group=False)

# %%
mean_return_by_q.head()
# Out:
#                         1         2         3
# factor_quantile
# 1               -0.000854 -0.001560 -0.003659
# 2               -0.000422 -0.000553  0.000044
# 3                0.000938  0.000481  0.000820
# 4                0.000194  0.000326  0.001216
# 5                0.000347  0.001469  0.001889

# %%
alphalens.plotting.plot_quantile_returns_bar(mean_return_by_q)

# %%
mean_return_by_q_daily, std_err = alphalens.performance.mean_return_by_quantile(factor_data, by_date=True)

# %%
mean_return_by_q_daily.head()
# Out:
#                                    1         2         3
# factor_quantile date
# 1               2009-12-31  0.012747  0.006678 -0.013121
#                 2010-01-31 -0.006954 -0.019555 -0.026607
#                 2010-02-28 -0.009217 -0.015092 -0.024271
#                 2010-03-31  0.016021  0.015250  0.014346
#                 2010-04-30 -0.018989 -0.015837 -0.031596

# %%
alphalens.plotting.plot_cumulative_returns_by_quantile(mean_return_by_q_daily)

# %%
ls_factor_returns = alphalens.performance.factor_returns(factor_data)

# %%
ls_factor_returns.head()
# Out:
#                    1         2         3
# date
# 2009-12-31 -0.008603 -0.011873  0.003942
# 2010-01-31  0.001124  0.019097  0.032375
# 2010-02-28  0.017649  0.033506  0.046978
# 2010-03-31 -0.004639 -0.009075 -0.010638
# 2010-04-30  0.017594  0.014659  0.015656

# %%
alphalens.plotting.plot_cumulative_returns(ls_factor_returns[3]);

# %%
alpha_beta = alphalens.performance.factor_alpha_beta(factor_data)

# %%
alpha_beta
# Out:
#                    1         2         3
# Ann. alpha  0.077018 -0.014898 -0.033256
# beta        0.026985  0.064934  0.071106

# %%
alphalens.tears.create_returns_tear_sheet(factor_data)
# Out:
# Returns Analysis
#                                                     1       2       3
# Ann. alpha                                      0.077  -0.015  -0.033
# beta                                            0.027   0.065   0.071
# Mean Period Wise Return Top Quantile (bps)      3.472   7.340   6.293
# Mean Period Wise Return Bottom Quantile (bps)  -8.535  -7.802 -12.210
# Mean Period Wise Spread (bps)                  11.512  12.479  16.442
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.py:647: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.py:942: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

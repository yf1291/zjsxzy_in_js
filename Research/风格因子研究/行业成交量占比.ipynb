# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
DATA_DIR = 'D:/Data/index/'

# %%
files = [f.rstrip('.xlsx') for f in os.listdir(DATA_DIR) if f.startswith('CI')]

# %%
dic = {}
for f in files:
    fname = '%s/%s.xlsx'%(DATA_DIR, f)
    temp = pd.read_excel(fname, index_col=0)
    dic[f] = temp['volume']
df = pd.DataFrame(dic)

# %%
df.head()
# Out:
#             CI005001.WI  CI005002.WI  CI005003.WI  CI005004.WI  CI005005.WI  \
# 2012-01-04  204041375.0  211368100.0  323145375.0  339342900.0  331353725.0
# 2012-01-05  186700550.0  183038000.0  300664325.0  374870375.0  313899125.0
# 2012-01-06  183207250.0  175890687.5  280419625.0  357947925.0  298457575.0
# 2012-01-09  253071775.0  487414100.0  590049900.0  466380750.0  444854700.0
# 2012-01-10  323835450.0  758297850.0  857765600.0  690294600.0  680088200.0
#
#              CI005006.WI  CI005007.WI  CI005008.WI  CI005009.WI   CI005010.WI  \
# 2012-01-04  5.110082e+08  247328625.0  279420950.0  105931800.0  5.528220e+08
# 2012-01-05  5.216450e+08  284214700.0  282990175.0  120761150.0  5.980462e+08
# 2012-01-06  4.908186e+08  237304350.0  253342375.0  121429725.0  5.407508e+08
# 2012-01-09  7.451376e+08  356430400.0  375446950.0  204075050.0  8.102814e+08
# 2012-01-10  1.079621e+09  667270800.0  655445800.0  295850650.0  1.244893e+09
#
# ...

# %%
df = df.div(df.sum(axis=1), axis='index')

# %%
plt.figure(figsize=(16, 9))
plt.plot(df['CI005021.WI'].rolling(window=20).mean())

# %%
from WindPy import w
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import preprocessing
import seaborn as sns
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
def wind2df(raw_data):
    dic = {}
    for data, field in zip(raw_data.Data, raw_data.Fields):
        dic[str(field.lower())] = data
    return pd.DataFrame(dic, index=raw_data.Times)

# %%
DATA_DIR = 'D:/Data/stocks'
INDEX_COMP_DIR = 'D:/Data/index-component'
code = '600000.SH'
fname = '%s/%s.xlsx'%(DATA_DIR, code)

# %%
df = pd.read_excel(fname, index_col=0)

# %%
df.head()
# Out:
#                      amt     close  dealnum      high       low  mfd_buyamt_a  \
# 2010-01-04  1.419984e+09  6.704699      NaN  6.919857  6.695207           NaN
# 2010-01-05  2.436891e+09  6.755325      NaN  6.828099  6.578136           NaN
# 2010-01-06  2.034174e+09  6.622433      NaN  6.739504  6.606613           NaN
# 2010-01-07  1.761801e+09  6.473721      NaN  6.657238  6.423096           NaN
# 2010-01-08  1.349532e+09  6.546495      NaN  6.581300  6.423096           NaN
#
#             mfd_sellamt_a  mkt_freeshares     pe_ttm  turnover       volume  \
# 2010-01-04            NaN    1.113943e+11  14.435065  0.012747   66191338.0
# 2010-01-05            NaN    1.122354e+11  14.287342  0.021712  115147943.0
# 2010-01-06            NaN    1.100275e+11  14.006279  0.018488   96782575.0
# 2010-01-07            NaN    1.075567e+11  13.691757  0.016380   85236072.0
# 2010-01-08            NaN    1.087658e+11  13.845673  0.012408   65707646.0
#
#                 vwap
# 2010-01-04  6.787826
# 2010-01-05  6.696198
# 2010-01-06  6.650270
# 2010-01-07  6.540061
# 2010-01-08  6.498539

# %% [markdown]
# # 收益率

# %%
df['ret'] = df['close'].pct_change()
df['20-day ret'] = df['ret'].rolling(window=20).mean()
df['20-day close'] = df['close'].rolling(window=20).mean()
df['20-day volume'] = df['volume'].rolling(window=20).mean()
df['20-day mfd_buyamt_a'] = df['mfd_buyamt_a'].rolling(window=20).sum()
df['20-day mfd_sellamt_a'] = df['mfd_sellamt_a'].rolling(window=20).sum()

# %% [markdown]
# # 波动率

# %%
df['volatility'] = df['ret'].rolling(window=20).std()

# %% [markdown]
# # 近一个月成交额

# %%
df['20-day amt'] = df['amt'].rolling(window=20).sum()

# %% [markdown]
# # 近一个月换手率

# %%
df['20-day turnover'] = df['turnover'].rolling(window=20).sum()

# %% [markdown]
# # 自由流通市值 / 价格

# %%
df['share_div_price'] = df['mkt_freeshares'] / df['close']

# %% [markdown]
# # Amihud(2002)的非流动性比率
# 单位成交额的收益率

# %%
df['amihud'] = np.abs(df['ret']) / df['amt']
df['20-day amihud'] = df['amihud'].rolling(window=20).mean()

# %% [markdown]
# # 流动性指标
# * 自由流通市值 / 价格
# * 近一个月成交额
# * 近一个月换手率
# * 近一个月价格均值
# * 近一个月收益率均值
# * 波动率

# %%
indicators = ['share_div_price',
              '20-day amt', 
              '20-day turnover', 
              '20-day close', 
              '20-day ret', 
              'volatility',
              '20-day amihud',
              '20-day mfd_buyamt_a',
              '20-day mfd_sellamt_a',
             ]

# %%
X = df[indicators].fillna(df[indicators].mean())

# %% [markdown]
# # 标准化

# %%
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %% [markdown]
# # PCA

# %%
pca = PCA()

# %%
pca.fit(X_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# ### 主成分贡献率

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.49214283,  0.21717876,  0.11140649,  0.08535048,  0.05343918,
#         0.02182386,  0.01424061,  0.00293392,  0.00148387])

# %% [markdown]
# ### Eigen value

# %%
centered_matrix = X_scaled - X_scaled.mean(axis=0)
cov = np.dot(centered_matrix.T, centered_matrix)
eigvals, eigvecs = np.linalg.eig(cov)

# %%
eigvals
# Out:
# array([ 8743.40945168,  3858.3979285 ,  1979.24769031,  1516.3365958 ,
#          949.40042304,   387.72262378,   252.9987475 ,    26.36250707,
#           52.12403232])

# %% [markdown]
# # 计算流动性指标
# $$F = \sum_{k=1}^{m} \frac{\lambda_k}{\sum_{i=1}^{m}\lambda_k}\times F_k$$

# %%
m = 4

# %%
F = np.dot(X_scaled, eigvecs[:, :m])

# %%
lambdas = eigvals[:m]
lambdas = lambdas / lambdas.sum()

# %%
F_score = np.dot(F, lambdas.T)

# %%
Fdf = pd.DataFrame({'F': F_score, 
                   'close': df['close'].values}, index=X.index)

# %%
Fdf['close_adj'] = preprocessing.StandardScaler().fit_transform(Fdf['close'].values.reshape(1, -1).T)

# %%
plt.figure(figsize=(16, 9))
Fdf['F'].plot(legend=True)
Fdf['close_adj'].plot(legend=True)

# %%
k = 5
Fdf['ret'] = Fdf['close'].pct_change(k).shift(-k)

# %%
sns.lmplot(x='F', y='ret', data=Fdf[Fdf.index >= '2016-03-01'])

# %%
Fdf['ret'].corr(Fdf['F'])
# Out:
# 0.1273314342706626

# %%
def liquidity_value(X):
    m = 3
    centered_matrix = X - X.mean(axis=0)
    cov = np.dot(centered_matrix.T, centered_matrix)
    eigvals, eigvecs = np.linalg.eig(cov)
    F = np.dot(X, eigvecs[:, :m])
    lambdas = eigvals[:m]
    lambdas = lambdas / lambdas.sum()
    F_score = np.dot(F, lambdas.T)
    return F_score

# %%
F_score = liquidity_value(X_scaled)

# %%
Fdf = pd.DataFrame({'F': F_score, 'close': df['close'].values}, index=X.index)

# %%
Fdf['close_adj'] = preprocessing.StandardScaler().fit_transform(Fdf['close'].values.reshape(1, -1).T)

# %%
plt.figure(figsize=(16, 9))
Fdf['F'].plot()
Fdf['close_adj'].plot()

# %%
Fdf.to_excel('C:/Users/zhangyang01/Desktop/F.xlsx')

# %% [markdown]
# # 全市场（加权）平均流动性

# %%
index = '000300.SH'
ind_df = pd.read_excel('%s/%s.xlsx'%(INDEX_COMP_DIR, index))

# %%
ind_df.head()
# Out:
#    i_weight sec_name  wind_code
# 0    0.7785     平安银行  000001.SZ
# 1    1.6134      万科A  000002.SZ
# 2    0.1184     神州高铁  000008.SZ
# 3    0.1667     中国宝安  000009.SZ
# 4    0.1702     中金岭南  000060.SZ

# %%
dic = {}
indicators = [
              '20-day amt', 
              '20-day turnover', 
              '20-day close', 
              '20-day ret', 
              'volatility',
              '20-day amihud',
              '20-day mfd_buyamt_a',
              '20-day mfd_sellamt_a',
             ]
for ticker in ind_df['wind_code']:
    fname = '%s/%s.xlsx'%(DATA_DIR, ticker)
    df = pd.read_excel(fname, index_col=0)
    df['ret'] = df['close'].pct_change()
    df['share_div_price'] = df['mkt_freeshares'] / df['close']
    df['20-day mfd_buyamt_a'] = df['mfd_buyamt_a'].rolling(window=20).sum()
    df['20-day mfd_sellamt_a'] = df['mfd_sellamt_a'].rolling(window=20).sum()
    df['20-day ret'] = df['ret'].rolling(window=20).mean()
    df['20-day close'] = df['close'].rolling(window=20).mean()
    df['20-day volume'] = df['volume'].rolling(window=20).mean()
    df['volatility'] = df['ret'].rolling(window=20).std()
    df['20-day amt'] = df['amt'].rolling(window=20).sum()
    df['amihud'] = np.abs(df['ret']) / df['amt']
    df['20-day amihud'] = df['amihud'].rolling(window=20).mean()
#     df['20-day free_turn'] = df['free_turn'].rolling(window=20).sum()
    df['20-day turnover'] = df['turnover'].rolling(window=20).sum()
    X = df[indicators].fillna(df[indicators].mean())
    scaler = preprocessing.StandardScaler().fit(X)
    X_scaled = scaler.transform(X)
    F_score = liquidity_value(X_scaled)
    df['liquidity'] = F_score
    dic[ticker] = df[['amt', 'volume', 'liquidity', 'close']]
pnl = pd.Panel(dic)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-ad2607a44645> in <module>()
#      12 for ticker in ind_df['wind_code']:
#      13     fname = '%s/%s.xlsx'%(DATA_DIR, ticker)
# ---> 14     df = pd.read_excel(fname, index_col=0)
#      15     df['ret'] = df['close'].pct_change()
#      16     df['share_div_price'] = df['mkt_freeshares'] / df['close']
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\util\_decorators.pyc in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\excel.pyc in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\io\excel.pyc in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\xlrd\__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     141                 formatting_info=formatting_info,
#     142                 on_demand=on_demand,
# --> 143                 ragged_rows=ragged_rows,
#     144                 )
#     145             return bk
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\xlrd\xlsx.pyc in open_workbook_2007_xml(zf, component_names, logfile, verbosity, use_mmap, formatting_info, on_demand, ragged_rows)
#     835         x12sheet = X12Sheet(sheet, logfile, verbosity)
#     836         heading = "Sheet %r (sheetx=%d) from %r" % (sheet.name, sheetx, fname)
# --> 837         x12sheet.process_stream(zflo, heading)
#     838         del zflo
#     839
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\xlrd\xlsx.pyc in own_process_stream(self, stream, heading)
#     546         for event, elem in ET.iterparse(stream):
#     547             if elem.tag == row_tag:
# --> 548                 self_do_row(elem)
#     549                 elem.clear() # destroy all child elements (cells)
#     550             elif elem.tag == U_SSML12 + "dimension":
#
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\xlrd\xlsx.pyc in do_row(self, row_elem)
#     662                         else: # start of row number; can't be '0'
#     663                             colx = colx - 1
# --> 664                             assert 0 <= colx < X12_MAX_COLS
#     665                             break
#     666                 except KeyError:
#
# KeyboardInterrupt:

# %%
# liqdf = pd.read_excel('C:/Users/jgtzsx01/Documents/workspace/zjsxzy_in_js/website/everyday-update/data/liquidity.xlsx', index_col=0)

# %%
# liqdf['zxb'].plot(figsize=(16, 9))

# %%
# liqdf.plot(figsize=(16, 9))

# %%
avg_liquidity = pnl.minor_xs('liquidity').mean(axis=1)

# %%
data = w.wsd('000300.SH', 'close', avg_liquidity.index[0].strftime('%Y-%m-%d'), avg_liquidity.index[-1].strftime('%Y-%m-%d'))

# %%
df = wind2df(data)

# %%
plt.figure(figsize=(16, 9))
avg_liquidity.rolling(window=5).sum().plot()
(df['close']/3500).plot()

# %%
k = 5
df['ret'] = df['close'].pct_change(k).shift(-k)

# %%
df['liquidity'] = avg_liquidity

# %%
df['ret'].corr(df['liquidity'])
# Out:
# 0.096313237179092889

# %%
sns.lmplot(x='liquidity', y='ret', data=df)

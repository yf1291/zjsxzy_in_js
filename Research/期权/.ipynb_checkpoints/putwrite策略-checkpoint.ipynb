# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import empyrical
from WindPy import w
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
# You can use w.menu to help yourself to create commands(WSD,WSS,WST,WSI,WSQ,...)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
def wind2df(raw_data):
    dic = {}
    for data, field in zip(raw_data.Data, raw_data.Fields):
        dic[field.lower()] = data
    if len(raw_data.Times) == len(raw_data.Data[0]):
        return pd.DataFrame(dic, index=raw_data.Times)
    else:
        return pd.DataFrame(dic)

# %%
df = pd.read_excel('./putwrite.xlsx', index_col=0)

# %%
df.head()
# Out:
#             510050.SH  wind_code  option  strike
# 2015-02-09      2.331   10000009  0.1268    2.35
# 2015-02-10      2.369   10000009  0.0975    2.35
# 2015-02-11      2.380   10000010  0.0992    2.40
# 2015-02-12      2.384   10000010  0.0888    2.40
# 2015-02-13      2.390   10000010  0.0730    2.40

# %%
data = w.wsd('H11025.CSI', 'close', df.index[0].strftime('%Y-%m-%d'), df.index[-1].strftime('%Y-%m-%d'))

# %%
df['bond'] = wind2df(data)['close']

# %%
df.head()
# Out:
#             510050.SH  wind_code  option  strike     bond
# 2015-02-09      2.331   10000009  0.1268    2.35  1324.49
# 2015-02-10      2.369   10000009  0.0975    2.35  1324.65
# 2015-02-11      2.380   10000010  0.0992    2.40  1324.87
# 2015-02-12      2.384   10000010  0.0888    2.40  1325.06
# 2015-02-13      2.390   10000010  0.0730    2.40  1325.24

# %%
plt.figure(figsize=(16, 9))
df['option'].plot()

# %%
plt.figure(figsize=(16, 9))
df['510050.SH'].plot()

# %% [markdown]
# # putwrite策略2
# 第一天买入可能最大亏损金额那么多的期权

# %%
df.loc[:, 'principle'] = 0.
df.loc[:, 'put'] = 0.
df.loc[:, 'margin'] = 0.
principle = 1000000.
one_piece = 10000
possible_loss = 0.5
number = int(principle / (df['strike'][0] * possible_loss) / one_piece)
margin = 0.13
df.loc[:, 'number'] = number

# %%
number
# Out:
# 102

# %%
df['put'] = -(number * df['option'] * one_piece)

# %%
df['margin'] = number * one_piece * df['510050.SH'] * margin

# %%
df.head()
# Out:
#             510050.SH  wind_code  option  strike     bond  principle  \
# 2016-03-01      1.971   10000580  0.1019    1.95  1372.34        0.0
# 2016-03-02      2.049   10000582  0.1186    2.05  1372.44        0.0
# 2016-03-03      2.053   10000582  0.1179    2.05  1372.54        0.0
# 2016-03-04      2.122   10000583  0.1150    2.10  1372.64        0.0
# 2016-03-07      2.111   10000583  0.1117    2.10  1372.92        0.0
#
#                  put    margin  number  interest sum           total
# 2016-03-01 -103938.0  261354.6     102      0.000000  1000000.000000
# 2016-03-02 -120972.0  271697.4     102     60.643907   983026.643907
# 2016-03-03 -120258.0  272227.8     102    121.244750   983801.244750
# 2016-03-04 -117300.0  281377.2     102    181.174573   986819.174573
# 2016-03-07 -113934.0  279918.6     102    349.263389   990353.263389

# %%
df['principle'] = (principle + df['option'][0] * number * one_piece) - df['margin']
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#             510050.SH  wind_code  option  strike     bond  principle  \
# 2016-03-01      1.971   10000580  0.1019    1.95  1372.34   842583.4
# 2016-03-02      2.049   10000582  0.1186    2.05  1372.44   832240.6
# 2016-03-03      2.053   10000582  0.1179    2.05  1372.54   831710.2
# 2016-03-04      2.122   10000583  0.1150    2.10  1372.64   822560.8
# 2016-03-07      2.111   10000583  0.1117    2.10  1372.92   824019.4
#
#                  put    margin  number  interest sum         total
# 2016-03-01 -103938.0  261354.6     102  29287.283614  1.050452e+06
# 2016-03-02 -120972.0  271697.4     102  29351.507167  1.036322e+06
# 2016-03-03 -120258.0  272227.8     102  29415.693834  1.036981e+06
# 2016-03-04 -117300.0  281377.2     102  29479.320323  1.039509e+06
# 2016-03-07 -113934.0  279918.6     102  29657.709456  1.042493e+06

# %%
df['interest sum'] = (df['bond'].pct_change() * df['principle']).cumsum()
df.loc[df.index[0], 'interest sum'] = 0
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#             510050.SH  wind_code  option  strike     bond  principle  \
# 2016-03-01      1.971   10000580  0.1019    1.95  1372.34   842583.4
# 2016-03-02      2.049   10000582  0.1186    2.05  1372.44   832240.6
# 2016-03-03      2.053   10000582  0.1179    2.05  1372.54   831710.2
# 2016-03-04      2.122   10000583  0.1150    2.10  1372.64   822560.8
# 2016-03-07      2.111   10000583  0.1117    2.10  1372.92   824019.4
#
#                  put    margin  number  interest sum         total
# 2016-03-01 -103938.0  261354.6     102      0.000000  1.050452e+06
# 2016-03-02 -120972.0  271697.4     102     60.643907  1.036322e+06
# 2016-03-03 -120258.0  272227.8     102    121.244750  1.036981e+06
# 2016-03-04 -117300.0  281377.2     102    181.174573  1.039509e+06
# 2016-03-07 -113934.0  279918.6     102    349.263389  1.042493e+06

# %%
df['total'] = df['principle'] + df['put'] + df['margin'] + df['interest sum']
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
plt.figure(figsize=(16, 9))
(df['total'] / principle).plot()
(1+df['510050.SH'].pct_change()).cumprod().plot()
# (-df['put']/principle).plot()
# (1+df['option'].pct_change()).cumprod().plot()

# %% [markdown]
# # putwrite策略2
# 每个月第一天买入可能最大亏损金额那么多的期权

# %%
months = pd.Series([(x.year, x.month) for x in df.index], index=df.index)
rebalance_dates = months.drop_duplicates(keep='first').index

# %%
df['principle'] = 0.
df['put'] = 0.
df['margin'] = 0.
df['number'] = 0
principle = 1000000.0
one_piece = 10000
possible_loss = 0.15
margin = 0.13
for date in df.index:
    if date in rebalance_dates:
        number = int(principle / (df.loc[date, 'strike'] * possible_loss) / one_piece)
    df.loc[date, 'number'] = number

# %%
df['put'] = -(df['number'] * df['option'] * one_piece)

# %%
df['margin'] = df['number'] * one_piece * df['510050.SH'] * margin

# %%
df['principle'] = (principle + df['option'][0] * number * one_piece) - df['margin']

# %%
df['interest sum'] = (df['bond'].pct_change() * df['principle']).cumsum()
df.loc[df.index[0], 'interest sum'] = 0

# %%
df['total'] = df['principle'] + df['put'] + df['margin'] + df['interest sum']

# %%
plt.figure(figsize=(16, 9))
(df['total'] / principle).plot()
(1+df['510050.SH'].pct_change()).cumprod().plot()
# (1+df['option'].pct_change()).cumprod().plot()

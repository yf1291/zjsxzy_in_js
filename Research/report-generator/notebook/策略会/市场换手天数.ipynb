# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from WindPy import w
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
data = w.wsd('881001.WI', 'close', '2010-01-01', '2019-03-19')

# %%
pdf = pd.DataFrame(data.Data[0], index=data.Times, columns=['881001.WI'])

# %%
df = pd.read_excel('D:/workspace/zjsxzy_in_js/website/everyday-update/data/881001.WI.xlsx')

# %%
df.tail()
# Out:
#             turnover days  current return  profit percentage
# 2019-03-13      42.884615        0.058062           0.685927
# 2019-03-14      42.028412        0.022920           0.539707
# 2019-03-15      41.398050        0.034857           0.612758
# 2019-03-18      40.649582        0.054050           0.734472
# 2019-03-19      40.327989        0.053829           0.723397

# %%
fig, ax = plt.subplots(figsize=(14, 4))
ax.plot(df['turnover days'], color='blue', label=u'换手天数')
ax.legend(fontsize=20)

ax11 = ax.twinx()
ax11.plot(pdf.index, pdf['881001.WI'], color='red', linewidth=1, label=u'万得全A')
# ax11.legend(loc='upper left', fontsize=20)
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax11.yaxis.set_tick_params(labelsize=20)

# %%
fig.savefig(u'./pic/市场换手天数.jpg', dpi=200, bbox_inches='tight')

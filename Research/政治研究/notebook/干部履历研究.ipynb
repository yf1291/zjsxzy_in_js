# %%
import pandas as pd

# %%
df = pd.read_excel('D:/Data/Full Data.xlsx', sheet_name=u'基本信息')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [姓名, 性别, 民族, 出生日期(YYYY-MM-DD), 籍贯省, 籍贯市, 籍贯县/区, 最高学历, 党派信息, 现状, 军队, 开除党籍, 查处/罢黜原因, 查处/罢黜原因备注, 是否复出, 查处/罢黜时间, 最初查处单位, 是否起诉, 起诉罪名, 涉案金额, 一审时间, 审理地点（一级地区关键词）, 审理地点（二级地区关键词）, 一审判决, 是否上诉, 二审时间, 二审判决]
# Index: []
#
# [0 rows x 27 columns]

# %%
df = df[df[u'性别'] == u'女']

# %%
index = df.index

# %%
df = pd.read_excel('D:/Data/Full Data.xlsx', sheet_name=u'全部经历')

# %%
df.head()
# Out:
#    用户编码   姓名  经历序号 起始时间（YYYY-MM-DD） 终止时间（（YYYY-MM-DD）） 是否全国性组织 是否中央派出  \
# 0     1  孙永春     1       1974-06-01         1976-12-01       否      否
# 1     1  孙永春     2       1976-12-01         1978-03-01       否      否
# 2     1  孙永春     3       1978-03-01         1978-10-01       否      否
# 3     1  孙永春     4       1978-10-01         1980-06-01       否      否
# 4     1  孙永春     5       1980-06-01         1984-08-01       否      否
#
#     一级关键词编码 地方一级关键词   二级关键词编码 ... 职务一级关键词编码     职务一级关键词  录入信息备注.1 职务二级关键词  \
# 0  370000.0     山东省  370500.0 ...      9637         西宋乡       NaN    大三合村
# 1  370000.0     山东省  370500.0 ...      1343       党委工作队       NaN     NaN
# 2  370000.0     山东省  370500.0 ...      9637         西宋乡       NaN     NaN
# 3  370000.0     山东省  370500.0 ...      1300  党委常委会/政治局        NaN     NaN
# 4  370000.0     山东省       NaN ...      4600        共青团委       NaN     NaN
#
#   职务三级关键词   具体职务    级别  标志位  学历 序号
# 0     NaN  团支部书记  小于副处    无  高中  1
# ...

# %%
df = df[df[u'用户编码'].isin(index)]

# %%
df.to_excel('D:/Data/female.xlsx', index=u'用户编码')

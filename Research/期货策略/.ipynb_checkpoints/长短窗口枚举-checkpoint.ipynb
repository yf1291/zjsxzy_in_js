# %%
import pandas as pd
import os
import empyrical

# %%
DATA_DIR = u'D:/workspace/zjsxzy_in_js/Research/期货策略/data/'

# %%
files = [f for f in os.listdir(DATA_DIR)]

# %%
dic = {}
for f in files:
    fname = u'%s/%s'%(DATA_DIR, f)
    temp = pd.read_excel(fname)
    dic[f.rstrip('.xlsx')] = temp['return']
df = pd.DataFrame(dic)

# %%
df.tail()
# Out:
#               10-100    10-105    10-110    10-115    10-120    10-125  \
# 2017-12-06  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2017-12-07  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2017-12-08  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2017-12-11  0.000000  0.000000  0.000000  0.000000  0.000000  0.016516
# 2017-12-12 -0.013143 -0.013143 -0.013143 -0.013143 -0.013143 -0.013143
#
#               10-130    10-135    10-140    10-145    ...         9-54  \
# 2017-12-06  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# 2017-12-07  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# 2017-12-08  0.000000  0.000000  0.000000  0.000000    ...     0.000000
# 2017-12-11  0.000000  0.000000  0.000000  0.000000    ...     0.016516
# 2017-12-12 -0.013143 -0.013143 -0.013143 -0.013143    ...    -0.013143
#
#                 9-59      9-64      9-69      9-74      9-79      9-84  \
# ...

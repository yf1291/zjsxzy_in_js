# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import alphalens
# Out:
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import sklearn.cluster
from sklearn.decomposition import PCA
import distance

# %%
stock = pd.read_excel('./data/assets.xlsx', sheet_name='equity')

# %%
# stock.head()

# %%
bond = pd.read_excel('./data/assets.xlsx', sheet_name='bond')

# %%
# bond.head()

# %%
oil = pd.read_excel('./data/assets.xlsx', sheet_name='oil')

# %%
# oil.head()

# %%
gold = pd.read_excel('./data/assets.xlsx', sheet_name='gold')

# %%
# gold.head()

# %%
house = pd.read_excel('./data/assets.xlsx', sheet_name='housing')

# %%
house.tail()
# Out:
#             House
# 2017-08-31  0.571
# 2017-09-30  0.473
# 2017-10-31  0.406
# 2017-11-30  0.390
# 2017-12-31  0.381

# %%
house['House'] = (1+house['House']/100.).cumprod()

# %%
house['House'].tail()
# Out:
# 2017-08-31    1.530959
# 2017-09-30    1.538200
# 2017-10-31    1.544446
# 2017-11-30    1.550469
# 2017-12-31    1.556376
# Name: House, dtype: float64

# %%
house['House'].resample('M').last().pct_change().tail()
# Out:
# 2017-08-31    0.00571
# 2017-09-30    0.00473
# 2017-10-31    0.00406
# 2017-11-30    0.00390
# 2017-12-31    0.00381
# Freq: M, Name: House, dtype: float64

# %%
money = pd.read_excel('./data/assets.xlsx', sheet_name='money')

# %%
# money.head()

# %%
df = stock.copy()
df = df.join(bond['0652.CS'], how='outer')
df = df.join(oil['Brent'], how='outer')
df = df.join(gold['Gold'], how='outer')
df = df.join(house['House'], how='outer')
# df['bond'] = bond['0652.CS']
# df['oil'] = oil['Brent']
# df['gold'] = gold['Gold']
# df['house'] = house['House']
# df['money'] = money['H11025.CSI']

# %%
df = df.fillna(method='ffill').dropna()

# %%
df.tail()
# Out:
#             881001.WI  0652.CS  Brent    Gold     House
# 2018-01-23  4738.2899  95.9913   69.4  1337.1  1.556376
# 2018-01-24  4757.4209  96.0056   69.4  1350.5  1.556376
# 2018-01-25  4738.2000  96.0152   69.4  1350.5  1.556376
# 2018-01-26  4743.2999  96.0248   69.4  1350.5  1.556376
# 2018-01-29  4674.0651  96.0321   69.4  1350.5  1.556376

# %%
ret_df = df.resample('M').last().pct_change()
ret_df = ret_df.dropna()

# %%
ret_df.tail()
# Out:
#             881001.WI   0652.CS     Brent      Gold    House
# 2017-09-30   0.012791  0.001405  0.082179 -0.014436  0.00473
# 2017-10-31   0.011057 -0.007306  0.075938 -0.009752  0.00406
# 2017-11-30  -0.029515 -0.005816  0.035534  0.006081  0.00390
# 2017-12-31  -0.002693 -0.001681  0.050370  0.011192  0.00381
# 2018-01-31   0.033463 -0.000403  0.040012  0.041651  0.00000

# %%
# pct_df = ret_df.rank(pct=True)

# %%
# sgn_df = ret_df.copy()
# sgn_df[sgn_df > 0] = 1
# sgn_df[sgn_df < 0] = -1

# %%
plt.figure(figsize=(16, 9))
plt.scatter(ret_df['881001.WI'], ret_df['0652.CS'])

# %%
def transition_matrix(labels, n):
    M = [[0]*n for _ in range(n)]
    for (i,j) in zip(labels, labels[1:]):
        M[i][j] += 1
    for row in M:
        m = sum(row)
        if m > 0:
            row[:] = [x*1./m for x in row]
    Mdf = pd.DataFrame(M, index=range(n), columns=range(n))
    return Mdf

# %%
affprop = sklearn.cluster.AffinityPropagation(damping=0.5, max_iter=200)
affprop.fit(ret_df)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#           damping=0.5, max_iter=200, preference=None, verbose=False)

# %%
affprop.labels_
# Out:
# array([ 5,  3, 10,  5,  9, 10, 11, 10, 11, 10,  0,  2,  3,  3,  1,  3,  9,
#         1,  3, 10,  1,  2,  2,  0, 10, 11,  3,  9,  9,  5, 11,  2,  0,  1,
#         5,  1,  3, 10,  2,  9, 11,  9,  3,  3,  9,  9,  9,  3,  2,  2,  2,
#         2,  6,  6,  6,  8,  5,  4,  5,  0,  1,  0,  9,  5,  2,  6,  7,  3,
#         5,  8, 11,  3,  6, 10,  9,  2, 11, 10,  3,  3,  9,  0,  9,  2, 10,
#         3, 11, 11,  9, 11,  3], dtype=int64)

# %%
affprop.cluster_centers_
# Out:
# array([[ -5.98621325e-02,   2.40437986e-04,  -7.43344656e-02,
#           3.91900718e-03,   7.00000000e-03],
#        [ -7.26238610e-02,   7.37117719e-03,  -2.81424204e-02,
#          -7.59976526e-02,  -2.98000000e-03],
#        [  5.40483691e-02,  -3.84274920e-03,  -7.00181081e-02,
#          -4.09262251e-02,   1.07000000e-02],
#        [  8.67720186e-03,   1.29296436e-02,   7.58136095e-03,
#           6.51825110e-02,   5.40000000e-03],
#        [  1.89637470e-01,   1.12808937e-02,   1.90165766e-01,
#           2.12423150e-02,  -1.00000000e-04],
#        [  1.50449380e-01,   2.19208056e-03,  -1.15805947e-02,
#          -1.15419746e-02,   4.50000000e-03],
#        [  5.33469486e-02,   1.14102211e-02,  -1.62817288e-01,
#           6.25207218e-03,   7.40000000e-03],
#        [ -2.75571809e-01,  -1.50828389e-03,  -9.47828462e-02,
#           4.76818075e-02,   4.20000000e-03],
#        [ -1.86010934e-02,  -1.05683207e-02,   2.41904762e-01,
#           3.31549935e-02,   1.45000000e-02],
#        [ -2.83864926e-02,  -9.70226444e-03,  -1.21310150e-03,
#          -1.38279799e-03,   6.94000000e-03],
#        [  1.61382241e-02,  -4.94678628e-04,   1.04290569e-01,
#           1.85803338e-02,   5.89000000e-03],
#        [  1.10567147e-02,  -7.30606719e-03,   7.59382673e-02,
#          -9.75173861e-03,   4.06000000e-03]])

# %%
# pd.DataFrame(affprop.cluster_centers_, columns=ret_df.columns).to_excel('C:/Users/zhangyang01/Desktop/temp.xlsx')

# %%
# kmeans = sklearn.cluster.KMeans(n_clusters=4)
# kmeans.fit(ret_df)

# %%
# kmeans.labels_

# %%
# kmeans.cluster_centers_

# %% [markdown]
# # 收益率（百分位）分布

# %%
def rank_percentile(array):
    """
    返回s的最后一个元素在s中的分位值
    """
    s = pd.Series(array)
    s = s.rank(pct=True)
    return s.iloc[-1]

# %%
pct_df = ret_df.rolling(window=36).apply(lambda x: rank_percentile(x))
pct_df = pct_df.dropna()

# %%
pct_df.tail()
# Out:
#             881001.WI   0652.CS     Brent      Gold     House
# 2017-09-30   0.444444  0.611111  0.805556  0.305556  0.361111
# 2017-10-31   0.444444  0.222222  0.750000  0.388889  0.250000
# 2017-11-30   0.194444  0.277778  0.694444  0.527778  0.222222
# 2017-12-31   0.416667  0.388889  0.722222  0.611111  0.194444
# 2018-01-31   0.666667  0.527778  0.694444  0.861111  0.111111

# %%
plt.figure(figsize=(16, 9))
plt.scatter(pct_df['881001.WI'], pct_df['Brent'])

# %%
pca = PCA()
pca.fit(pct_df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.34336882,  0.20413672,  0.17957311,  0.14304896,  0.12987239])

# %%
tran_df = pca.transform(pct_df)

# %%
plt.figure(figsize=(16, 9))
plt.scatter(tran_df[:, 0], tran_df[:, 1])

# %%
affprop = sklearn.cluster.AffinityPropagation(damping=0.5, max_iter=200)
affprop.fit(pct_df)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#           damping=0.5, max_iter=200, preference=None, verbose=False)

# %%
affprop.labels_
# Out:
# array([0, 0, 0, 0, 1, 3, 1, 0, 4, 2, 2, 2, 1, 1, 2, 3, 3, 3, 3, 4, 3, 3, 3,
#        3, 1, 4, 4, 4, 4, 4, 4, 4], dtype=int64)

# %%
affprop.cluster_centers_
# Out:
# array([[ 0.03333333,  0.36666667,  0.25      ,  0.4       ,  0.63333333],
#        [ 0.73333333,  0.95      ,  0.03333333,  0.6       ,  0.76666667],
#        [ 0.66666667,  0.5       ,  0.95      ,  0.4       ,  1.        ],
#        [ 0.38333333,  0.26666667,  0.46666667,  0.45      ,  0.78333333],
#        [ 0.38333333,  0.4       ,  0.8       ,  0.66666667,  0.28333333]])

# %% [markdown]
# # 预测大类资产下期收益策略

# %%
ret_df
# Out:
#             881001.WI   0652.CS     Brent      Gold    House
# 2010-07-31   0.118664  0.002727  0.034161 -0.058444 -0.00670
# 2010-08-31   0.025408  0.001087 -0.025677  0.056079 -0.00460
# 2010-09-30   0.010649 -0.003104  0.069660  0.062829  0.01090
# 2010-10-31   0.120092 -0.009061  0.021047  0.019641  0.00950
# 2010-11-30  -0.042457 -0.016915  0.043046  0.028614  0.01060
# 2010-12-31  -0.008895  0.002524  0.083818  0.025636  0.01020
# 2011-01-31  -0.020329 -0.002749  0.061568 -0.054423  0.01410
# 2011-02-28   0.053114 -0.000851  0.134384  0.057180  0.00930
# 2011-03-31   0.001902  0.001200  0.041596  0.015074  0.00770
# 2011-04-30  -0.013642  0.001245  0.082521  0.069881  0.00680
# 2011-05-31  -0.059862  0.000240 -0.074334  0.003919  0.00700
# 2011-06-30   0.024038 -0.006112 -0.046680 -0.018868  0.00490
# 2011-07-31  -0.010226 -0.008408  0.037776  0.070126  0.00380
# 2011-08-31  -0.045905 -0.002709  0.004744  0.131526  0.00070
# 2011-09-30  -0.088791  0.004104 -0.094952 -0.107886 -0.00040
# 2011-10-31   0.043137  0.010919  0.028552  0.054635 -0.00326
# 2011-11-30  -0.050502  0.008706  0.025731 -0.008149 -0.00551
# 2011-12-31  -0.072624  0.007371 -0.028142 -0.075998 -0.00298
# 2012-01-31   0.032414  0.004605  0.020076  0.103842 -0.00165
# 2012-02-29   0.071090 -0.005420  0.108562  0.028769 -0.00433
# 2012-03-31  -0.068881 -0.000047  0.009654 -0.071169 -0.00321
# 2012-04-30   0.059095 -0.000875 -0.038490  0.001054 -0.00384
# 2012-05-31  -0.000423  0.012025 -0.124726 -0.057143 -0.00657
# 2012-06-30  -0.050788  0.000258 -0.093299  0.001276  0.00294
# 2012-07-31  -0.055393 -0.000391  0.124881  0.033928  0.00366
# 2012-08-31  -0.024177 -0.007569  0.075522  0.021568  0.00292
# 2012-09-30   0.023903 -0.003833 -0.022558  0.074348  0.00270
# 2012-10-31  -0.009142 -0.001353 -0.013200 -0.035373  0.00135
# 2012-11-30  -0.059600 -0.000352  0.008645  0.005966  0.00414
# 2012-12-31   0.150424 -0.001067 -0.000361 -0.037176  0.00227
# ...               ...       ...       ...       ...      ...
# 2015-08-31  -0.153464  0.002801 -0.099831  0.042081  0.00950
# 2015-09-30  -0.059194  0.001050 -0.014176 -0.002665  0.00280
# 2015-10-31   0.171016  0.007575  0.015014  0.022494  0.00300
# 2015-11-30   0.062075 -0.003138 -0.088958 -0.080244  0.00460
# 2015-12-31   0.053347  0.011410 -0.162817  0.006252  0.00740
# 2016-01-31  -0.275572 -0.001508 -0.094783  0.047682  0.00420
# 2016-02-29  -0.026862 -0.000674  0.083887  0.108950  0.00600
# 2016-03-31   0.164302  0.002313  0.023107 -0.000446  0.01900
# 2016-04-30  -0.018601 -0.010568  0.241905  0.033155  0.01450
# 2016-05-31  -0.004634  0.000710  0.079316 -0.050216  0.01700
# 2016-06-30   0.034700  0.003438 -0.024564  0.087980  0.01320
# 2016-07-31   0.005269  0.005263 -0.151717  0.011769  0.01630
# 2016-08-31   0.047258  0.001236  0.176153 -0.013546  0.02170
# 2016-09-30  -0.017347  0.000784  0.006258  0.010232  0.02830
# 2016-10-31   0.031544  0.000640 -0.042289 -0.040440  0.01650
# 2016-11-30   0.039409 -0.011865  0.037879 -0.068121  0.00880
# 2016-12-31  -0.053596 -0.015091  0.146194 -0.023834  0.00750
# 2017-01-31  -0.002531 -0.006543  0.005277  0.034251  0.00537
# 2017-02-28   0.031579 -0.003988 -0.034208  0.044294  0.00511
# 2017-03-31  -0.005822 -0.004069 -0.021739 -0.008148  0.00972
# 2017-04-30  -0.029369 -0.008520 -0.052490  0.019208  0.00789
# 2017-05-31  -0.028386 -0.009702 -0.001213 -0.001383  0.00694
# 2017-06-30   0.048025  0.008822 -0.046964 -0.016260  0.00615
# 2017-07-31   0.016138 -0.000495  0.104291  0.018580  0.00589
# 2017-08-31   0.030502 -0.004312  0.013464  0.031153  0.00571
# 2017-09-30   0.012791  0.001405  0.082179 -0.014436  0.00473
# 2017-10-31   0.011057 -0.007306  0.075938 -0.009752  0.00406
# 2017-11-30  -0.029515 -0.005816  0.035534  0.006081  0.00390
# 2017-12-31  -0.002693 -0.001681  0.050370  0.011192  0.00381
# 2018-01-31   0.033463 -0.000403  0.040012  0.041651  0.00000
#
# [91 rows x 5 columns]

# %%
# K = 10
W = 36
pred_df = pd.DataFrame(index=ret_df.index, columns=ret_df.columns)
for i, date in enumerate(ret_df.index):
    past_return = ret_df[ret_df.index <= date][-W:]
    if past_return.shape[0] >= W:
#         print date
        past_return = past_return.rank(pct=True, axis=1)
#         kmeans = sklearn.cluster.KMeans(n_clusters=K)
#         kmeans.fit(past_return)
        affprop = sklearn.cluster.AffinityPropagation()
        affprop.fit(past_return)
        label = affprop.labels_[-1]
#         print affprop.labels_.max()
        tran = transition_matrix(affprop.labels_, affprop.labels_.max()+1)
        prob = tran.loc[label].values
        if prob.sum() == 0:
            pred_df.loc[date] = affprop.cluster_centers_[label]
        else:
            pred = affprop.cluster_centers_.T.dot(prob)
            pred_df.loc[date] = pred

# %%
# plt.figure(figsize=(16, 9))
# plt.scatter(pred_df['881001.WI'], ret_df['881001.WI'].shift(-1))

# %%
pred_df.tail()
# Out:
#            881001.WI   0652.CS     Brent      Gold     House
# 2017-09-30  0.566667       0.5       0.5  0.733333       0.7
# 2017-10-31       0.6  0.485714  0.571429  0.657143  0.685714
# 2017-11-30      0.72      0.48      0.56      0.56      0.68
# 2017-12-31  0.633333  0.466667  0.633333       0.6  0.666667
# 2018-01-31       0.7      0.45      0.55      0.65      0.65

# %%
pred_df = pred_df.dropna()
pricing = df[df.index >= pred_df.index[0]].resample('M').last()

# %%
factor_df = pred_df.stack()
factor_df.index = factor_df.index.set_names(['date', 'asset'])

# %%
factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor_df, pricing, quantiles=5, periods=(1,2,3), max_loss=0.35)
# Out:
# Dropped 25.0% entries from factor data (5.4% after in forward returns computation and 19.6% in binning phase). Set max_loss=0 to see potentially suppressed Exceptions.

# %%
mean_return_by_q, std_err_by_q = alphalens.performance.mean_return_by_quantile(factor_data, by_group=False)

# %%
alphalens.plotting.plot_quantile_returns_bar(mean_return_by_q)

# %%
alphalens.tears.create_returns_tear_sheet(factor_data)
# Out:
# Returns Analysis
#                                                      1        2        3
# Ann. alpha                                       4.592    3.264    1.943
# beta                                            -0.804   -0.429   -0.278
# Mean Period Wise Return Top Quantile (bps)      51.249   49.954   11.748
# Mean Period Wise Return Bottom Quantile (bps)  -59.382  -73.184  -76.091
# Mean Period Wise Spread (bps)                  110.631  136.009  104.714
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.py:647: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# C:\Users\zhangyang01\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.py:942: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

# %%
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy
import datetime
import os
from WindPy import w
from scipy.stats import stats
from sklearn import linear_model
from sklearn import preprocessing
# %matplotlib inline

# %%
pnl = pd.read_pickle('C:/Users/jgtzsx01/Documents/workspace/zjsxzy_in_js/website/everyday-update/data/price.pkl')

# %%
df = pd.read_csv('C:/Users/jgtzsx01/Documents/workspace/zjsxzy_in_js/website/everyday-update/data/881001.WI.csv', index_col=1)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.shape[0]
# Out:
# 1822

# %%
wdf = pd.read_excel('C:/Users/jgtzsx01/Documents/workspace/zjsxzy_in_js/website/everyday-update/data/881001_weight.xlsx', index_col=0)

# %%
wdf = wdf[wdf.index.map(lambda x: x in pnl.items)]

# %%
wdf.head()
# Out:
#            证券名称        权重
# Wind代码
# 000001.SZ  平安银行  0.338145
# 000002.SZ   万科A  0.825451
# 000004.SZ  国农科技  0.005935
# 000005.SZ  世纪星源  0.018782
# 000006.SZ  深振业A  0.036380

# %%
wdf.sort_index().head()
# Out:
#            证券名称        权重
# Wind代码
# 000001.SZ  平安银行  0.338145
# 000002.SZ   万科A  0.825451
# 000004.SZ  国农科技  0.005935
# 000005.SZ  世纪星源  0.018782
# 000006.SZ  深振业A  0.036380

# %%
wdf = wdf.sort_index()

# %%
df = df[(df.index >= pnl.major_axis[0]) & (df.index <= pnl.major_axis[-1])]

# %%
df.index = pnl.major_axis[1:]

# %%
df.shape
# Out:
# (1394, 2)

# %%
pnl.shape
# Out:
# (3137, 1395, 5)

# %%
df.head()
# Out:
#                              close  return
# 2011-10-11 00:00:00.005  2296.5129     NaN
# 2011-10-12 00:00:00.005  2367.7161     NaN
# 2011-10-13 00:00:00.005  2389.1013     NaN
# 2011-10-14 00:00:00.005  2380.6648     NaN
# 2011-10-17 00:00:00.005  2390.9915     NaN

# %%
df['return'] = df['close'].pct_change(25)

# %%
pnl.ix[:, :, 'return'] = pnl.minor_xs('close').pct_change(25)

# %%
pnl.ix[:, :, 'return sqr'] = pnl.minor_xs('return') ** 2

# %%
pnl.minor_xs('return sqr').multiply(wdf[u'权重']**2, axis=1).tail()
# Out:
#                          000001.SZ  000002.SZ  000004.SZ     000005.SZ  \
# 2017-06-28 00:00:00.005   0.000854   0.065886   0.000003  3.075605e-07
# 2017-06-29 00:00:00.005   0.000606   0.064794   0.000003  3.261435e-08
# 2017-06-30 00:00:00.005   0.000496   0.061814   0.000003  3.063532e-07
# 2017-07-03 00:00:00.005   0.000124   0.026857   0.000003  5.061364e-09
# 2017-07-04 00:00:00.005   0.000080   0.017677   0.000003  1.314667e-09
#
#                             000006.SZ  000007.SZ     000008.SZ  000009.SZ  \
# 2017-06-28 00:00:00.005  1.569957e-06        0.0  2.431685e-08   0.000019
# 2017-06-29 00:00:00.005  9.715560e-06        0.0  1.842276e-06   0.000073
# 2017-06-30 00:00:00.005  1.016863e-05        0.0  5.902759e-06   0.000062
# 2017-07-03 00:00:00.005  2.220841e-06        0.0  6.198327e-07   0.000043
# 2017-07-04 00:00:00.005  1.849163e-07        0.0  2.756448e-06   0.000057
#
#                             000010.SZ  000011.SZ      ...       603987.SH  \
# 2017-06-28 00:00:00.005  1.718146e-07   0.000005      ...        0.000005
# 2017-06-29 00:00:00.005  4.146389e-08   0.000002      ...        0.000004
# 2017-06-30 00:00:00.005  6.636744e-08   0.000004      ...        0.000004
# 2017-07-03 00:00:00.005  9.404309e-08   0.000002      ...        0.000004
# 2017-07-04 00:00:00.005  2.185483e-07   0.000002      ...        0.000004
#
#                             603988.SH     603989.SH     603990.SH  \
# 2017-06-28 00:00:00.005  4.707844e-08  4.476505e-07  9.407239e-09
# 2017-06-29 00:00:00.005  2.549144e-09  2.437511e-06  5.318039e-08
# 2017-06-30 00:00:00.005  1.991552e-10  1.307228e-06  3.230424e-08
# 2017-07-03 00:00:00.005  3.242550e-09  2.856965e-06  5.060211e-08
# 2017-07-04 00:00:00.005  7.621350e-09  2.176825e-06  3.941934e-08
#
#                             603991.SH  603993.SH     603996.SH     603997.SH  \
# 2017-06-28 00:00:00.005  3.030166e-08   0.000082  3.112482e-07  3.354541e-06
# 2017-06-29 00:00:00.005  1.457296e-07   0.000113  1.108786e-06  3.149907e-06
# 2017-06-30 00:00:00.005  1.625111e-07   0.000131  3.753239e-07  3.654241e-07
# 2017-07-03 00:00:00.005  1.428614e-07   0.000135  1.758716e-07  3.380833e-07
# 2017-07-04 00:00:00.005  1.273690e-07   0.000088  1.249760e-08  4.966532e-08
#
#                             603998.SH     603999.SH
# 2017-06-28 00:00:00.005  1.088865e-10  2.898230e-07
# 2017-06-29 00:00:00.005  2.529732e-08  2.466178e-06
# 2017-06-30 00:00:00.005  2.684210e-07  2.673806e-06
# 2017-07-03 00:00:00.005  2.882316e-07  2.650375e-05
# 2017-07-04 00:00:00.005  2.183399e-07  2.905628e-05
#
# [5 rows x 3137 columns]

# %%
concentration = (df['return']**2) * (wdf[u'权重']**2).sum() / pnl.minor_xs('return sqr').multiply(wdf[u'权重']**2, axis=1).sum(axis=1)[1:]

# %%
plt.figure(figsize=(16, 9))
scaler = preprocessing.MinMaxScaler()
plt.plot(concentration)
plt.plot(df.index, scaler.fit_transform(df['close']))
# Out:
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
plt.figure(figsize=(16, 9))
plt.plot(concentration[concentration.index >= '2016-03-15'])

# %%
concentration.sort(ascending=False)
# Out:
# C:\Users\jgtzsx01\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   if __name__ == '__main__':

# %%
concentration
# Out:
# 2016-03-16 00:00:00.005    2.889402
# 2016-03-21 00:00:00.005    2.766720
# 2016-03-18 00:00:00.005    2.717188
# 2016-03-17 00:00:00.005    2.652443
# 2015-09-16 00:00:00.005    2.564981
# 2015-06-15 00:00:00.005    2.555078
# 2015-06-12 00:00:00.005    2.526304
# 2015-09-15 00:00:00.005    2.516600
# 2016-03-11 00:00:00.005    2.479262
# 2016-03-10 00:00:00.005    2.473979
# 2015-06-11 00:00:00.005    2.438932
# 2015-06-16 00:00:00.005    2.367394
# 2015-06-10 00:00:00.005    2.348796
# 2015-09-14 00:00:00.005    2.322334
# 2016-03-15 00:00:00.005    2.297980
# 2015-06-03 00:00:00.005    2.275528
# 2015-06-17 00:00:00.005    2.267774
# 2016-03-04 00:00:00.005    2.265303
# 2016-03-09 00:00:00.005    2.263871
# 2015-06-05 00:00:00.005    2.259699
# 2016-03-14 00:00:00.005    2.248937
# 2015-09-18 00:00:00.005    2.228285
# 2015-09-17 00:00:00.005    2.227968
# 2015-06-09 00:00:00.005    2.221945
# 2016-03-08 00:00:00.005    2.206132
# 2016-03-22 00:00:00.005    2.202719
# 2016-03-23 00:00:00.005    2.187206
# 2016-03-29 00:00:00.005    2.181267
# 2015-09-10 00:00:00.005    2.176530
# 2016-03-07 00:00:00.005    2.172346
#                              ...
# 2011-11-22 00:00:00.005         NaN
# 2011-11-23 00:00:00.005         NaN
# 2011-11-24 00:00:00.005         NaN
# 2011-11-25 00:00:00.005         NaN
# 2011-11-28 00:00:00.005         NaN
# 2011-11-29 00:00:00.005         NaN
# 2011-11-30 00:00:00.005         NaN
# 2011-12-01 00:00:00.005         NaN
# 2011-12-02 00:00:00.005         NaN
# 2011-12-05 00:00:00.005         NaN
# 2011-12-06 00:00:00.005         NaN
# 2011-12-07 00:00:00.005         NaN
# 2011-12-08 00:00:00.005         NaN
# 2011-12-09 00:00:00.005         NaN
# 2011-12-12 00:00:00.005         NaN
# 2011-12-13 00:00:00.005         NaN
# 2011-12-14 00:00:00.005         NaN
# 2011-12-15 00:00:00.005         NaN
# 2011-12-16 00:00:00.005         NaN
# 2011-12-19 00:00:00.005         NaN
# 2011-12-20 00:00:00.005         NaN
# 2011-12-21 00:00:00.005         NaN
# 2011-12-22 00:00:00.005         NaN
# 2011-12-23 00:00:00.005         NaN
# 2011-12-26 00:00:00.005         NaN
# 2011-12-27 00:00:00.005         NaN
# 2011-12-28 00:00:00.005         NaN
# 2011-12-29 00:00:00.005         NaN
# 2011-12-30 00:00:00.005         NaN
# 2012-01-04 00:00:00.005         NaN
# dtype: float64

# %%
import pandas as pd

# %%
DATA_DIR = '\\\\hg-pubshare\HFM各部门共享\资产配置投资研究中心\张炀\股票池'

# %%
def p2f(x):
    return float(x.rstrip('%')) / 100

# %%
df = pd.read_excel('%s/股票池.xlsx'%(DATA_DIR), converters={'增速(2020)': p2f})

# %%
df
# Out:
#         主题行业  股票名称  细分行业    收盘价      上次预测时间   短评   长评 增速(2020) 增速(2021)  \
# 0       金融地产  中国平安    保险  82.80  2019-12-27  2.0  1.0     0.09      18%
# 1       金融地产  中国太保    保险  31.68  2019-12-27  2.0  1.0     0.01      21%
# 2       金融地产  招商银行    银行  37.27  2020-04-30  1.0  1.0     0.18      16%
# 3       金融地产  宁波银行    银行  31.65  2020-07-13  1.0  1.0     0.17      16%
# 4       金融地产  兴业银行    银行  16.48  2020-04-29  2.0  2.0     0.09      10%
# ..       ...   ...   ...    ...         ...  ...  ...      ...      ...
# 399  其他经济不敏感  牧原股份  畜禽养殖  96.98  2020-07-07  1.0  2.0     4.83     -43%
# 400  其他经济不敏感  中航沈飞  航空装备  65.42  2020-07-03  2.0  1.0     0.11      10%
# 401  其他经济不敏感  温氏股份  畜禽养殖  24.33  2020-04-24  2.0  1.0      1.8     -29%
# 402  其他经济不敏感  白云机场    机场  15.02  2020-07-14  1.0  2.0     0.66      20%
# 403  其他经济不敏感  开润股份  其他纺织  28.41         NaN  NaN  NaN      NaN      NaN
#
#     增速(2022)   pe(2020)   pe(2021)   pe(2022)  内部池(40%)  外部池(20%)  基金重仓池(20%)  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import empyrical
# %matplotlib inline

# %%
assets_fname = u'../data/资产.xlsx'

# %%
names = [u'翁兆宇', u'张炀', u'曹越奇', u'潘弘林']

# %%
df = pd.read_excel(assets_fname, index_col=0, sheetname='Sheet1')

# %%
df.tail()
# Out:
#             000906.SH    065.CS  SPGSCITR.SPI  H11025.CSI
# 2018-01-04  4516.4509  173.5471       2588.49   1456.3802
# 2018-01-05  4524.4135  173.6709       2565.06   1456.5571
# 2018-01-08  4547.0283  173.8006       2565.18   1457.0725
# 2018-01-09  4570.4453  173.8590       2592.36   1457.2464
# 2018-01-10  4578.0282  173.7565       2604.75   1457.4182

# %%
ret_df = df.pct_change().dropna()

# %%
(1+ret_df).cumprod().plot()

# %%
est = pd.read_excel(assets_fname, index_col=0, sheetname='Sheet2')

# %%
est = est / 100

# %%
est['avg'] = est.mean(axis=1)

# %%
(1+est['avg']).cumprod().plot()

# %% [markdown]
# # 计算波动率

# %%
vol_df = ret_df.resample('BM').last().rolling(window=12).apply(lambda x: empyrical.annual_volatility(x, period='monthly'))

# %%
vol_df.dropna().tail()
# Out:
#             000906.SH    065.CS  SPGSCITR.SPI  H11025.CSI
# 2017-10-31   0.012487  0.003106      0.058372    0.000290
# 2017-11-30   0.015889  0.002105      0.040096    0.000283
# 2017-12-29   0.016039  0.001733      0.039833    0.000280
# 2018-01-31   0.016123  0.001783      0.039936    0.000313

# %%
est_vol = est['avg'].rolling(window=12).apply(lambda x: empyrical.annual_volatility(x, period='monthly'))

# %%
est_vol.tail()
# Out:
# 2017-07-31    0.013385
# 2017-08-31    0.013303
# 2017-09-30    0.007508
# 2017-10-31    0.006972
# 2017-11-30    0.007024
# Name: avg, dtype: float64

# %%
vol_df['estate'] = est_vol

# %%
vol_df = vol_df.fillna(0)

# %%
vol_df.tail()
# Out:
#             000906.SH    065.CS  SPGSCITR.SPI  H11025.CSI    estate
# 2017-09-29   0.000000  0.000000      0.000000    0.000000  0.000000
# 2017-10-31   0.012487  0.003106      0.058372    0.000290  0.006972
# 2017-11-30   0.015889  0.002105      0.040096    0.000283  0.007024
# 2017-12-29   0.016039  0.001733      0.039833    0.000280  0.000000
# 2018-01-31   0.016123  0.001783      0.039936    0.000313  0.000000

# %% [markdown]
# # 根据打分计算风险权重、资产权重

# %%
for name in names:
    print name
    fname = u'../data/%s-打分.xlsx'%(name)
    score = pd.read_excel(fname, index_col=0)
    print score
#     current = vol_df[vol_df.index == score.index[-1]]
#     current.loc[:, 'Real Estate'] = est_vol[-1]
    money_per = score['Cash']
    score['Cash'] = 0
    weight_df = pd.DataFrame(index=score.index, columns=score.columns)
    for date in score.index:
        last_vol = vol_df[vol_df.index <= date].iloc[-1]
        weight = score.loc[date] / last_vol.values
        weight_df.loc[date] = weight
    weight_df['Cash'] = weight_df.sum(axis=1) * money_per / (1 - money_per)
    weight_df = weight_df.div(weight_df.sum(axis=1), axis='index')
    print weight_df
    fname = u'../data/%s-权重.xlsx'%(name)
    weight_df.to_excel(fname)
#     score = score[['Equity', 'Bond', 'Commodity', 'Cash', 'Real Estate']]
#     weight = score.iloc[-1].values / current
#     weight = weight.div(weight.sum(axis=1), axis='index')
#     fname = u'../data/%s-权重.xlsx'%(name)
#     weight_df = pd.read_excel(fname)
#     if weight_df.index[-1] == weight.index[-1]:
#         continue
#     print weight_df
#     print weight
#     weight.columns = weight_df.columns
#     print weight
#     weight_df = weight_df.append(weight)
#     print weight_df
#     weight_df.to_excel(fname)
# Out:
# 翁兆宇
#             Equity  Bond  Commodity  Cash  Real Estate
# 2017-11-13     1.8   1.6        3.4     0          1.0
# 2017-12-25     2.4   1.8        3.0     0          1.2
#               Equity      Bond  Commodity Cash Real Estate
# 2017-11-13  0.167432   0.59833  0.0676533    0    0.166585
# 2017-12-25  0.120661  0.683108  0.0597673    0    0.136464
# 张炀
#             Equity  Bond  Commodity  Cash  Real Estate
# 2017-11-13     3.4   1.6        2.8   0.0          0.2
# 2017-12-25     3.0   1.4        3.2   0.4          0.0
#               Equity      Bond  Commodity Cash Real Estate
# 2017-11-13  0.315119  0.596171  0.0555134    0   0.0331968
# 2017-12-25  0.121327   0.42739  0.0512829  0.4           0
# 曹越奇
#             Equity  Bond  Commodity  Cash  Real Estate
# 2017-11-13     2.6   2.4        2.6   0.0          1.8
# 2017-12-25     1.2   1.9        2.4   0.4          0.9
#                Equity      Bond  Commodity Cash Real Estate
# 2017-11-13   0.162212   0.60197  0.0346997    0    0.201118
# 2017-12-25  0.0388581  0.464424  0.0307963  0.4   0.0659211
# 潘弘林
#             Equity  Bond  Commodity  Cash  Real Estate
# 2017-11-13     2.4   1.8        2.0   0.0          0.2
# 2017-12-25     2.0   2.4        2.2   0.2          0.4
#                Equity      Bond  Commodity Cash Real Estate
# 2017-11-13   0.230271  0.694314   0.041049    0    0.034366
# 2017-12-25  0.0730828  0.661999  0.0318563  0.2   0.0330618

# %% [markdown]
# # 计算每人收益率

# %%
fname = u'../data/%s-权重.xlsx'%(names[1])
weight_df = pd.read_excel(fname, index_col=0)

# %%
weight_df
# Out:
#               Equity      Bond  Commodity  Cash  Real Estate
# 2017-11-13  0.315119  0.596171   0.055513   0.0     0.033197
# 2017-12-25  0.121327  0.427390   0.051283   0.4     0.000000

# %%
ret_df = ret_df[ret_df.index >= weight_df.index[0]]
ret_df['Real Estate'] = est[est.index >= weight_df.index[0]]['avg']
ret_df = ret_df.fillna(0)
ret_df.columns = weight_df.columns

# %%
# prev_weight = weight_df.iloc[0]
# daily_weight.iloc[0] = prev_weight
daily_weight = pd.DataFrame(columns=ret_df.columns, index=ret_df.index)
for date in ret_df.index:
    if date in weight_df.index:
        daily_weight.loc[date] = weight_df.loc[date]
    else:
        daily_weight.loc[date] = (1 + ret_df.loc[date]) * prev_weight
#     print (1 + ret_df.loc[date]), prev_weight, (1 + ret_df.loc[date]) * prev_weight, daily_weight.loc[date]
    prev_weight = daily_weight.loc[date]
daily_weight = daily_weight.div(daily_weight.sum(axis=1), axis='index')

# %%
daily_weight
# Out:
#               Equity      Bond  Commodity      Cash Real Estate
# 2017-11-13  0.315119  0.596171  0.0555134         0   0.0331968
# 2017-11-14  0.313898  0.597947  0.0548416         0   0.0333138
# 2017-11-15  0.312274  0.599502  0.0548253         0   0.0333991
# 2017-11-16  0.313642  0.598559  0.0544694         0   0.0333296
# 2017-11-17  0.312232  0.599044    0.05537         0   0.0333536
# 2017-11-20  0.313844  0.597921  0.0549438         0   0.0332912
# 2017-11-21  0.316905  0.594997  0.0549487         0   0.0331489
# 2017-11-22  0.317332  0.593978   0.055531         0   0.0331588
# 2017-11-23   0.31112  0.599369  0.0560453         0   0.0334659
# 2017-11-24  0.310998  0.599276  0.0562893         0   0.0334369
# 2017-11-27  0.308167  0.601935  0.0563207         0   0.0335771
# 2017-11-28  0.309411  0.600927  0.0561329         0   0.0335293
# 2017-11-29   0.30954  0.601145  0.0557852         0   0.0335293
# 2017-11-30  0.307162  0.603353  0.0557275         0   0.0337578
# 2017-12-01  0.307064   0.60286  0.0563548         0   0.0337211
# 2017-12-04  0.307673  0.603047   0.055568         0   0.0337119
# 2017-12-05  0.307182  0.603583  0.0555003         0   0.0337345
# 2017-12-06  0.306881  0.604786  0.0545368         0   0.0337957
# 2017-12-07  0.304711  0.606447  0.0549527         0   0.0338894
# 2017-12-08  0.306474  0.604483  0.0552582         0   0.0337849
# 2017-12-11  0.309754  0.601226  0.0554012         0   0.0336189
# 2017-12-12  0.307461  0.603751  0.0550161         0   0.0337722
# 2017-12-13  0.309305  0.602432  0.0545628         0    0.033701
# 2017-12-14  0.308261  0.603026  0.0549885         0   0.0337249
# 2017-12-15  0.305914  0.605005   0.055264         0   0.0338169
# 2017-12-18  0.305638  0.605108  0.0554437         0     0.03381
# 2017-12-19  0.307994  0.602853  0.0554672         0   0.0336856
# 2017-12-20  0.307238  0.603138  0.0559177         0   0.0337061
# 2017-12-21  0.308993  0.601391   0.056003         0    0.033613
# 2017-12-22   0.30842  0.601727  0.0562274         0   0.0336256
# 2017-12-25  0.121327   0.42739  0.0512829       0.4           0
# 2017-12-26  0.121606  0.426724  0.0521657  0.399504           0
# 2017-12-27  0.120182  0.427307  0.0522937  0.400218           0
# 2017-12-28  0.120816  0.426867  0.0525122  0.399804           0
# 2017-12-29  0.121194  0.426602  0.0527625  0.399442           0
# 2018-01-02  0.122583     0.426  0.0526842  0.398733           0
# 2018-01-03  0.123217  0.425449  0.0531353  0.398199           0
# 2018-01-04  0.123679  0.425115  0.0531882  0.398017           0
# 2018-01-05  0.123886  0.425381  0.0527021  0.398031           0
# 2018-01-08  0.124371   0.42524  0.0526477  0.397742           0
# 2018-01-09  0.124838  0.424792  0.0531318  0.397238           0
# 2018-01-10  0.125013  0.424433   0.053372  0.397182           0

# %%
dic = {}
ret_df['Real Estate'] = est[est.index >= weight_df.index[0]]['avg']
ret_df = ret_df.fillna(0)
ret_df = ret_df[ret_df.index >= weight_df.index[0]]
ret_df.columns = weight_df.columns
for name in names:
    print name
    fname = u'../data/%s-权重.xlsx'%(name)
    weight_df = pd.read_excel(fname, index_col=0)
    
    daily_weight = pd.DataFrame(columns=ret_df.columns, index=ret_df.index)
    for date in ret_df.index:
        if date in weight_df.index:
            daily_weight.loc[date] = weight_df.loc[date]
        else:
            daily_weight.loc[date] = (1 + ret_df.loc[date]) * prev_weight
        prev_weight = daily_weight.loc[date]
    daily_weight = daily_weight.div(daily_weight.sum(axis=1), axis='index')
    
    daily_weight.to_excel(u'../data/%s-每日权重.xlsx'%(name))
    dic[name] = (daily_weight * ret_df).sum(axis=1)
return_df = pd.DataFrame(dic)
# Out:
# 翁兆宇
# 张炀
# 曹越奇
# 潘弘林

# %% [markdown]
# # 综合打分

# %%
weight_dic = {}
for name in names:
    weight_dic[name] = pd.read_excel(u'../data/%s-每日权重.xlsx'%(name))

# %%
weight_weight = 2.5 * weight_dic[u'翁兆宇'] + \
                1.0 * weight_dic[u'张炀'] + \
                1.0 * weight_dic[u'曹越奇'] + \
                1.0 * weight_dic[u'潘弘林']

# %%
weight_weight = weight_weight / 5.5

# %%
weight_weight.to_excel(u'../data/综合打分.xlsx')

# %%
return_df[u'综合'] = (ret_df * weight_weight).sum(axis=1)

# %%
return_df
# Out:
#                   张炀       曹越奇       潘弘林       翁兆宇        综合
# 2017-11-13  0.000465 -0.000126  0.000030 -0.000165 -0.000008
# 2017-11-14 -0.003494 -0.002051 -0.002700 -0.002595 -0.002679
# 2017-11-15 -0.002539 -0.001308 -0.001843 -0.001441 -0.001690
# 2017-11-16  0.002093  0.001199  0.001657  0.001088  0.001394
# 2017-11-17 -0.000698 -0.000235 -0.000478  0.000256 -0.000140
# 2017-11-20  0.001889  0.000935  0.001376  0.000782  0.001119
# 2017-11-21  0.004337  0.002078  0.003013  0.002298  0.002759
# 2017-11-22 -0.000288 -0.000676 -0.000723 -0.000324 -0.000454
# 2017-11-23 -0.009001 -0.004673 -0.006615 -0.004820 -0.005880
# 2017-11-24  0.000867  0.000688  0.000820  0.000862  0.000824
# 2017-11-27 -0.004138 -0.002070 -0.002954 -0.002258 -0.002692
# 2017-11-28  0.001434  0.000649  0.000979  0.000614  0.000836
# 2017-11-29  0.000002  0.000070  0.000093 -0.000133 -0.000031
# 2017-11-30 -0.003263 -0.000935 -0.002247 -0.001256 -0.001743
# 2017-12-01  0.001096  0.000717  0.000875  0.001131  0.001003
# 2017-12-04  0.000283  0.000234  0.000351 -0.000206  0.000064
# 2017-12-05 -0.000667 -0.000287 -0.000429 -0.000361 -0.000416
# 2017-12-06 -0.001793 -0.000977 -0.001267 -0.001609 -0.001466
# 2017-12-07 -0.002740 -0.001377 -0.001997 -0.001271 -0.001689
# 2017-12-08  0.003111  0.001596  0.002228  0.001926  0.002136
# 2017-12-11  0.004993  0.002463  0.003520  0.002793  0.003265
# 2017-12-12 -0.004509 -0.002481 -0.003383 -0.002915 -0.003211
# 2017-12-13  0.002130  0.001030  0.001529  0.000875  0.001250
# 2017-12-14 -0.000702 -0.000234 -0.000436 -0.000026 -0.000261
# 2017-12-15 -0.002693 -0.001197 -0.001814 -0.001178 -0.001573
# 2017-12-18  0.000205  0.000237  0.000248  0.000345  0.000282
# 2017-12-19  0.003718  0.001913  0.002698  0.002107  0.002472
# 2017-12-20 -0.000602 -0.000302 -0.000471 -0.000070 -0.000282
# 2017-12-21  0.002785  0.001413  0.001997  0.001599  0.001853
# 2017-12-22 -0.000370 -0.000112 -0.000220 -0.000003 -0.000129
# 2017-12-25 -0.000305  0.000101 -0.000070 -0.000361 -0.000214
# 2017-12-26  0.001378  0.000680  0.000762  0.001437  0.001166
# 2017-12-27 -0.001643 -0.000579 -0.001115 -0.001752 -0.001403
# 2017-12-28  0.001162  0.000526  0.000752  0.001188  0.000983
# 2017-12-29  0.001034  0.000585  0.000790  0.001137  0.000955
# 2018-01-02  0.002295  0.001165  0.001712  0.002313  0.001992
# 2018-01-03  0.001475  0.000713  0.000964  0.001553  0.001279
# 2018-01-04  0.000580  0.000176  0.000264  0.000490  0.000408
# 2018-01-05  0.000093  0.000162  0.000330  0.000146  0.000173
# 2018-01-08  0.001082  0.000689  0.000940  0.001128  0.001006
# 2018-01-09  0.001396  0.000749  0.000984  0.001523  0.001261
# 2018-01-10  0.000259 -0.000005 -0.000081  0.000104  0.000078

# %%
(1+return_df).cumprod().to_excel(u'../data/净值.xlsx')

# %%
return_df
# Out:
#                   张炀       曹越奇       潘弘林       翁兆宇        综合
# 2017-11-13  0.000465 -0.000126  0.000030 -0.000165 -0.000008
# 2017-11-14 -0.003494 -0.002051 -0.002700 -0.002595 -0.002679
# 2017-11-15 -0.002539 -0.001308 -0.001843 -0.001441 -0.001690
# 2017-11-16  0.002093  0.001199  0.001657  0.001088  0.001394
# 2017-11-17 -0.000698 -0.000235 -0.000478  0.000256 -0.000140
# 2017-11-20  0.001889  0.000935  0.001376  0.000782  0.001119
# 2017-11-21  0.004337  0.002078  0.003013  0.002298  0.002759
# 2017-11-22 -0.000288 -0.000676 -0.000723 -0.000324 -0.000454
# 2017-11-23 -0.009001 -0.004673 -0.006615 -0.004820 -0.005880
# 2017-11-24  0.000867  0.000688  0.000820  0.000862  0.000824
# 2017-11-27 -0.004138 -0.002070 -0.002954 -0.002258 -0.002692
# 2017-11-28  0.001434  0.000649  0.000979  0.000614  0.000836
# 2017-11-29  0.000002  0.000070  0.000093 -0.000133 -0.000031
# 2017-11-30 -0.003263 -0.000935 -0.002247 -0.001256 -0.001743
# 2017-12-01  0.001096  0.000717  0.000875  0.001131  0.001003
# 2017-12-04  0.000283  0.000234  0.000351 -0.000206  0.000064
# 2017-12-05 -0.000667 -0.000287 -0.000429 -0.000361 -0.000416
# 2017-12-06 -0.001793 -0.000977 -0.001267 -0.001609 -0.001466
# 2017-12-07 -0.002740 -0.001377 -0.001997 -0.001271 -0.001689
# 2017-12-08  0.003111  0.001596  0.002228  0.001926  0.002136
# 2017-12-11  0.004993  0.002463  0.003520  0.002793  0.003265
# 2017-12-12 -0.004509 -0.002481 -0.003383 -0.002915 -0.003211
# 2017-12-13  0.002130  0.001030  0.001529  0.000875  0.001250
# 2017-12-14 -0.000702 -0.000234 -0.000436 -0.000026 -0.000261
# 2017-12-15 -0.002693 -0.001197 -0.001814 -0.001178 -0.001573
# 2017-12-18  0.000205  0.000237  0.000248  0.000345  0.000282
# 2017-12-19  0.003718  0.001913  0.002698  0.002107  0.002472
# 2017-12-20 -0.000602 -0.000302 -0.000471 -0.000070 -0.000282
# 2017-12-21  0.002785  0.001413  0.001997  0.001599  0.001853
# 2017-12-22 -0.000370 -0.000112 -0.000220 -0.000003 -0.000129
# 2017-12-25 -0.000305  0.000101 -0.000070 -0.000361 -0.000214
# 2017-12-26  0.001378  0.000680  0.000762  0.001437  0.001166
# 2017-12-27 -0.001643 -0.000579 -0.001115 -0.001752 -0.001403
# 2017-12-28  0.001162  0.000526  0.000752  0.001188  0.000983
# 2017-12-29  0.001034  0.000585  0.000790  0.001137  0.000955
# 2018-01-02  0.002295  0.001165  0.001712  0.002313  0.001992
# 2018-01-03  0.001475  0.000713  0.000964  0.001553  0.001279
# 2018-01-04  0.000580  0.000176  0.000264  0.000490  0.000408
# 2018-01-05  0.000093  0.000162  0.000330  0.000146  0.000173
# 2018-01-08  0.001082  0.000689  0.000940  0.001128  0.001006
# 2018-01-09  0.001396  0.000749  0.000984  0.001523  0.001261
# 2018-01-10  0.000259 -0.000005 -0.000081  0.000104  0.000078

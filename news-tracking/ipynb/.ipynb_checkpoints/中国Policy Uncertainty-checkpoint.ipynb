# %%
import jieba
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR = 'D:/workspace/data/wallstreetcn'
WORD_DIR = u'D:/Data/词库'
CAIJING_WORD_FILE = u'%s/THUOCL_caijing.txt'%(WORD_DIR)

# %%
jieba.load_userdict(CAIJING_WORD_FILE)

# %%
fname = '%s/2018/3053715.txt'%(DATA_DIR)

# %%
with open(fname, 'r') as fp:
    text = fp.readlines()

# %%
time = text[0].decode('utf-8').split('_')[0]

# %%
time
# Out:
# u'2018-01-05 07:30'

# %%
date = time.split(' ')[0]

# %%
date
# Out:
# u'2018-01-05'

# %%
content = " ".join(text[1:])

# %%
print content
# Out:
#  美好的一天，从阅读“财富晨报”开始~1、央行302号文重拳规范债券代持加高杠杆。2、银监会：推动金融资源进一步向“三农”倾斜。3、上交所划出2018年监管重点：实控人将被穿透式“照看”。4、shibor连续第三天全面下行，隔夜下跌5.85个基点。5、瑞波币大涨29%突破3美元，过去一年上涨495倍。6、上海市已形成建设自由贸易港初步方案，并报送国家相关部委征求意见。7、“信联”揭开神秘面纱：8家筹备平台分别占股8%。8、飞天茅台零售价每瓶涨200元，仍然一瓶难求。9、欧盟重要新金融法规MiFID II生效，为投资者提供更大保障。10、美联储12月会议纪要：加息可能因为税改来得更快。People don’t leave because thing are hard. They leave because it’s no longer worth it. 人们会放弃，往往不是因为难度问题，而是因为，不再值得继续下去。编辑：陈霞 杨娜

# %%
content = jieba.cut(content)

# %%
doc = set([word for word in content if (not word in stop_words)])

# %%
def uncertainty(word_set):
    words1 = [u'政策', u'支出', u'预算', u'政治', u'利率', u'改革']
    flag1 = False
    for w in words1:
        if w in word_set:
            flag1 = True
            break
    if not flag1:
        return False
    words2 = [u'政府', u'背景', u'权威', u'官方']
    flag2 = False
    for w in words2:
        if w in word_set:
            flag2 = True
            break
    if not flag2:
        return False
    words3 = [u'央行', u'税收', u'监管', u'规定', u'中央银行', u'中国人民银行', u'赤字', u'TWO']
    for w in words3:
        if w in word_set:
            return True
    return False

# %%
uncertainty(doc)
# Out:
# False

# %%
df = pd.read_excel('D:/Data/risk/policy_uncertainty.xlsx')

# %%
df.index = pd.to_datetime(df.index)

# %%
df = df.rolling(window=20).sum()

# %%
df[df.index >= '2014-01-01'].head()
# Out:
#              pol    tot
# 2014-01-01  91.0  629.0
# 2014-01-02  85.0  624.0
# 2014-01-03  87.0  648.0
# 2014-01-04  89.0  647.0
# 2014-01-05  86.0  623.0

# %%
df['un'] = df['pol'] / df['tot']

# %%
df['un'].plot(figsize=(16, 9))

# %%
df['mean'] = df['un'].rolling(window=500).mean()
df['std'] = df['un'].rolling(window=500).std()

# %%
df['z'] = (df['un'] - df['mean']) / df['std']

# %%
df['z'].plot(figsize=(16, 9))
